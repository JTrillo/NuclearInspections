# %% [markdown]
# # Real case - Analyst times (5 Peers)

# %% [markdown]
# ### Imports

# %%
import threading
import requests
import json
import random
import plotly
import plotly.graph_objs as go
from analyst import *

# %% [markdown]
# ### Global variables

# %%
API_ENDPOINT = "http://104.155.2.231:3000/api/"
NS = "ertis.uma.nuclear"

# %% [markdown]
# ### Function

# %%
def addAnalysisTest(num_analysts, num_acqs):
    analyst_threads = []
    analysis_per_worker = int(num_acqs/num_analysts)
    
    # Check for next analysis id
    resource_url = f"{API_ENDPOINT}{NS}.Analysis"
    r = requests.get(resource_url)
    next_id = len(r.json()) + 1
    
    # Create threads
    for i in range(num_analysts):
        thread = Analyst(i, f"Analyst-{i}", analysis_per_worker, next_id+analysis_per_worker*i, API_ENDPOINT, NS)
        analyst_threads.append(thread)
        
    # Start threads
    for i in range(num_analysts):
        analyst_threads[i].start()
        
    # Join threads
    for i in range(num_analysts):
        analyst_threads[i].join()
        
    # Print results
    min_get = analyst_threads[0].min_get
    avg_get = analyst_threads[0].avg_get
    max_get = analyst_threads[0].max_get
    min_add = analyst_threads[0].min_add
    avg_add = analyst_threads[0].avg_add
    max_add = analyst_threads[0].max_add
    analyst_threads[0].printResults()
    for i in range(1, num_analysts):
        if analyst_threads[i].min_get < min_get:
            min_get = analyst_threads[i].min_get

        avg_get = avg_get + analyst_threads[i].avg_get

        if analyst_threads[i].max_get > max_get:
            max_get = analyst_threads[i].max_get
            
        if analyst_threads[i].min_add < min_add:
            min_add = analyst_threads[i].min_add
            
        avg_add = avg_add + analyst_threads[i].avg_add
        
        if analyst_threads[i].max_get > max_get:
            max_add = analyst_threads[i].max_add

        analyst_threads[i].printResults()

    print(f"MIN GET ACQ --> {min_get}")
    print(f"AVG GET ACQ --> {avg_get/num_analysts}")
    print(f"MAX GET ACQ --> {max_get}")
    print(f"MIN ADD ANA --> {min_add}")
    print(f"AVG ADD ANA --> {avg_add/num_analysts}")
    print(f"MAX ADD ANA --> {max_add}")

    print("Add Analysis Test Finalized")

# %% [markdown]
# ### Execution of the test (100 analysis to do) with one single analyst

# %%
addAnalysisTest(1, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-0 has finished
# Analyst-0 - Fastest acquisition gotten in 0.12400674819946289 seconds
# Analyst-0 - Slowest acquisition gotten in 0.20801210403442383 seconds
# Analyst-0 - Average time getting acquisitions: 0.14027803659439086 seconds
# Analyst-0 - Fastest analysis added in 2.3351337909698486 seconds
# Analyst-0 - Slowest analysis added in 3.235184907913208 seconds
# Analyst-0 - Average time adding analysis: 2.4125579977035523 seconds
# MIN GET ACQ --> 0.12400674819946289
# AVG GET ACQ --> 0.14027803659439086
# MAX GET ACQ --> 0.20801210403442383
# MIN ADD ANA --> 2.3351337909698486
# AVG ADD ANA --> 2.4125579977035523
# MAX ADD ANA --> 3.235184907913208
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with two (2) analysts

# %%
addAnalysisTest(2, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has started
# Analyst Analyst-1 has finished
# Analyst Analyst-0 has finished
# Analyst-0 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-0 - Slowest acquisition gotten in 0.20701169967651367 seconds
# Analyst-0 - Average time getting acquisitions: 0.1445082426071167 seconds
# Analyst-0 - Fastest analysis added in 0.46802687644958496 seconds
# Analyst-0 - Slowest analysis added in 2.519144058227539 seconds
# Analyst-0 - Average time adding analysis: 2.331833367347717 seconds
# Analyst-1 - Fastest acquisition gotten in 0.12300705909729004 seconds
# Analyst-1 - Slowest acquisition gotten in 0.21001195907592773 seconds
# Analyst-1 - Average time getting acquisitions: 0.146528377532959 seconds
# Analyst-1 - Fastest analysis added in 1.5950913429260254 seconds
# Analyst-1 - Slowest analysis added in 2.531144857406616 seconds
# Analyst-1 - Average time adding analysis: 2.36193510055542 seconds
# MIN GET ACQ --> 0.12300705909729004
# AVG GET ACQ --> 0.14551831007003785
# MAX GET ACQ --> 0.21001195907592773
# MIN ADD ANA --> 0.46802687644958496
# AVG ADD ANA --> 2.3468842339515685
# MAX ADD ANA --> 2.519144058227539
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with five (5) analysts

# %%
addAnalysisTest(5, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
# Analyst Analyst-2 has started
# Analyst Analyst-3 has started
# Analyst Analyst-4 has started
#
# Analyst Analyst-2 has finished
# Analyst Analyst-0 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-3 has finished
# Analyst Analyst-4 has finished
# Analyst-0 - Fastest acquisition gotten in 0.12300729751586914 seconds
# Analyst-0 - Slowest acquisition gotten in 0.3450195789337158 seconds
# Analyst-0 - Average time getting acquisitions: 0.1618592619895935 seconds
# Analyst-0 - Fastest analysis added in 0.4630265235900879 seconds
# Analyst-0 - Slowest analysis added in 2.4621407985687256 seconds
# Analyst-0 - Average time adding analysis: 2.171524167060852 seconds
# Analyst-1 - Fastest acquisition gotten in 0.126007080078125 seconds
# Analyst-1 - Slowest acquisition gotten in 0.39602231979370117 seconds
# Analyst-1 - Average time getting acquisitions: 0.16135917901992797 seconds
# Analyst-1 - Fastest analysis added in 0.4220240116119385 seconds
# Analyst-1 - Slowest analysis added in 2.522144079208374 seconds
# Analyst-1 - Average time adding analysis: 2.173174285888672 seconds
# Analyst-2 - Fastest acquisition gotten in 0.12300682067871094 seconds
# Analyst-2 - Slowest acquisition gotten in 0.37502145767211914 seconds
# Analyst-2 - Average time getting acquisitions: 0.16965970993041993 seconds
# Analyst-2 - Fastest analysis added in 0.8490486145019531 seconds
# Analyst-2 - Slowest analysis added in 2.501142978668213 seconds
# Analyst-2 - Average time adding analysis: 2.230427587032318 seconds
# Analyst-3 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-3 - Slowest acquisition gotten in 0.3580203056335449 seconds
# Analyst-3 - Average time getting acquisitions: 0.16730953454971315 seconds
# Analyst-3 - Fastest analysis added in 0.41002321243286133 seconds
# Analyst-3 - Slowest analysis added in 2.52014422416687 seconds
# Analyst-3 - Average time adding analysis: 2.2123765349388123 seconds
# Analyst-4 - Fastest acquisition gotten in 0.1260073184967041 seconds
# Analyst-4 - Slowest acquisition gotten in 0.3760213851928711 seconds
# Analyst-4 - Average time getting acquisitions: 0.16195926666259766 seconds
# Analyst-4 - Fastest analysis added in 0.358020544052124 seconds
# Analyst-4 - Slowest analysis added in 2.503143310546875 seconds
# Analyst-4 - Average time adding analysis: 2.062317907810211 seconds
# MIN GET ACQ --> 0.12300682067871094
# AVG GET ACQ --> 0.1644293904304504
# MAX GET ACQ --> 0.39602231979370117
# MIN ADD ANA --> 0.358020544052124
# AVG ADD ANA --> 2.169964096546173
# MAX ADD ANA --> 2.4621407985687256
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with ten (10) analysts

# %%
addAnalysisTest(10, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
#
# Analyst Analyst-2 has started
# Analyst Analyst-3 has started
# Analyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has startedAnalyst Analyst-7 has started
#
# Analyst Analyst-8 has started
# Analyst Analyst-9 has started
# Analyst Analyst-8 has finished
# Analyst Analyst-9 has finished
# Analyst Analyst-2 has finished
# Analyst Analyst-0 has finished
# Analyst Analyst-5 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-7 has finished
# Analyst Analyst-4 has finishedAnalyst Analyst-3 has finished
#
# Analyst Analyst-6 has finished
# Analyst-0 - Fastest acquisition gotten in 0.1410081386566162 seconds
# Analyst-0 - Slowest acquisition gotten in 0.5850334167480469 seconds
# Analyst-0 - Average time getting acquisitions: 0.20711185932159423 seconds
# Analyst-0 - Fastest analysis added in 1.173067331314087 seconds
# Analyst-0 - Slowest analysis added in 2.5631468296051025 seconds
# Analyst-0 - Average time adding analysis: 2.1745244026184083 seconds
# Analyst-1 - Fastest acquisition gotten in 0.1390078067779541 seconds
# Analyst-1 - Slowest acquisition gotten in 0.6010341644287109 seconds
# Analyst-1 - Average time getting acquisitions: 0.22351281642913817 seconds
# Analyst-1 - Fastest analysis added in 0.356020450592041 seconds
# Analyst-1 - Slowest analysis added in 2.491142749786377 seconds
# Analyst-1 - Average time adding analysis: 2.0189154148101807 seconds
# Analyst-2 - Fastest acquisition gotten in 0.13600802421569824 seconds
# Analyst-2 - Slowest acquisition gotten in 0.6130349636077881 seconds
# Analyst-2 - Average time getting acquisitions: 0.20521173477172852 seconds
# Analyst-2 - Fastest analysis added in 0.41202354431152344 seconds
# Analyst-2 - Slowest analysis added in 2.4621407985687256 seconds
# Analyst-2 - Average time adding analysis: 1.9380108833312988 seconds
# Analyst-3 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-3 - Slowest acquisition gotten in 0.5920336246490479 seconds
# Analyst-3 - Average time getting acquisitions: 0.19261105060577394 seconds
# Analyst-3 - Fastest analysis added in 2.009114980697632 seconds
# Analyst-3 - Slowest analysis added in 2.391136884689331 seconds
# Analyst-3 - Average time adding analysis: 2.3065319538116453 seconds
# Analyst-4 - Fastest acquisition gotten in 0.12500715255737305 seconds
# Analyst-4 - Slowest acquisition gotten in 0.5660324096679688 seconds
# Analyst-4 - Average time getting acquisitions: 0.2028115510940552 seconds
# Analyst-4 - Fastest analysis added in 0.6500372886657715 seconds
# Analyst-4 - Slowest analysis added in 2.5611467361450195 seconds
# Analyst-4 - Average time adding analysis: 1.9954142570495605 seconds
# Analyst-5 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-5 - Slowest acquisition gotten in 0.6100349426269531 seconds
# Analyst-5 - Average time getting acquisitions: 0.20531179904937744 seconds
# Analyst-5 - Fastest analysis added in 0.4930284023284912 seconds
# Analyst-5 - Slowest analysis added in 2.4311389923095703 seconds
# Analyst-5 - Average time adding analysis: 2.17382435798645 seconds
# Analyst-6 - Fastest acquisition gotten in 0.12900757789611816 seconds
# Analyst-6 - Slowest acquisition gotten in 0.5770330429077148 seconds
# Analyst-6 - Average time getting acquisitions: 0.19721133708953859 seconds
# Analyst-6 - Fastest analysis added in 0.9730556011199951 seconds
# Analyst-6 - Slowest analysis added in 2.4681408405303955 seconds
# Analyst-6 - Average time adding analysis: 2.026015830039978 seconds
# Analyst-7 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-7 - Slowest acquisition gotten in 0.597034215927124 seconds
# Analyst-7 - Average time getting acquisitions: 0.22421281337738036 seconds
# Analyst-7 - Fastest analysis added in 0.7910451889038086 seconds
# Analyst-7 - Slowest analysis added in 2.388136863708496 seconds
# Analyst-7 - Average time adding analysis: 2.0142151594161986 seconds
# Analyst-8 - Fastest acquisition gotten in 0.14000797271728516 seconds
# Analyst-8 - Slowest acquisition gotten in 0.5660324096679688 seconds
# Analyst-8 - Average time getting acquisitions: 0.21351211071014403 seconds
# Analyst-8 - Fastest analysis added in 0.5080292224884033 seconds
# Analyst-8 - Slowest analysis added in 2.416138172149658 seconds
# Analyst-8 - Average time adding analysis: 2.0794190168380737 seconds
# Analyst-9 - Fastest acquisition gotten in 0.13100743293762207 seconds
# Analyst-9 - Slowest acquisition gotten in 0.590033769607544 seconds
# Analyst-9 - Average time getting acquisitions: 0.21541233062744142 seconds
# Analyst-9 - Fastest analysis added in 0.3870220184326172 seconds
# Analyst-9 - Slowest analysis added in 2.395137071609497 seconds
# Analyst-9 - Average time adding analysis: 1.8691069602966308 seconds
# MIN GET ACQ --> 0.1240072250366211
# AVG GET ACQ --> 0.2086919403076172
# MAX GET ACQ --> 0.6130349636077881
# MIN ADD ANA --> 0.356020450592041
# AVG ADD ANA --> 2.0595978236198422
# MAX ADD ANA --> 2.5631468296051025
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with twenty five (25) analysts

# %%
addAnalysisTest(25, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has startedAnalyst Analyst-2 has started
# Analyst Analyst-3 has started
#
# Analyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has startedAnalyst Analyst-7 has started
#
# Analyst Analyst-8 has started
# Analyst Analyst-9 has startedAnalyst Analyst-10 has startedAnalyst Analyst-11 has started
# Analyst Analyst-12 has started
# Analyst Analyst-13 has started
#
#
# Analyst Analyst-14 has startedAnalyst Analyst-15 has started
#
# Analyst Analyst-16 has started
# Analyst Analyst-17 has startedAnalyst Analyst-18 has started
#
# Analyst Analyst-19 has started
# Analyst Analyst-20 has started
# Analyst Analyst-21 has started
# Analyst Analyst-22 has startedAnalyst Analyst-23 has started
# Analyst Analyst-24 has started
#
# Analyst Analyst-9 has finished
# Analyst Analyst-19 has finished
# Analyst Analyst-22 has finished
# Analyst Analyst-0 has finishedAnalyst Analyst-2 has finished
# Analyst Analyst-5 has finished
# Analyst Analyst-18 has finished
#
# Analyst Analyst-16 has finished
# Analyst Analyst-3 has finished
# Analyst Analyst-23 has finished
# Analyst Analyst-4 has finished
# Analyst Analyst-20 has finished
# Analyst Analyst-15 has finishedAnalyst Analyst-10 has finished
#
# Analyst Analyst-6 has finishedAnalyst Analyst-11 has finished
#
# Analyst Analyst-12 has finishedAnalyst Analyst-1 has finished
#
# Analyst Analyst-21 has finished
# Analyst Analyst-17 has finishedAnalyst Analyst-24 has finished
# Analyst Analyst-8 has finished
#
# Analyst Analyst-13 has finished
# Analyst Analyst-14 has finished
# Analyst Analyst-7 has finished
# Analyst-0 - Fastest acquisition gotten in 0.2540144920349121 seconds
# Analyst-0 - Slowest acquisition gotten in 1.1480653285980225 seconds
# Analyst-0 - Average time getting acquisitions: 0.5390306711196899 seconds
# Analyst-0 - Fastest analysis added in 0.6860394477844238 seconds
# Analyst-0 - Slowest analysis added in 2.418138265609741 seconds
# Analyst-0 - Average time adding analysis: 1.788602352142334 seconds
# Analyst-1 - Fastest acquisition gotten in 0.1480083465576172 seconds
# Analyst-1 - Slowest acquisition gotten in 1.1450655460357666 seconds
# Analyst-1 - Average time getting acquisitions: 0.4720269441604614 seconds
# Analyst-1 - Fastest analysis added in 0.39402246475219727 seconds
# Analyst-1 - Slowest analysis added in 2.727155923843384 seconds
# Analyst-1 - Average time adding analysis: 2.0043646693229675 seconds
# Analyst-2 - Fastest acquisition gotten in 0.12900757789611816 seconds
# Analyst-2 - Slowest acquisition gotten in 1.1570661067962646 seconds
# Analyst-2 - Average time getting acquisitions: 0.46352648735046387 seconds
# Analyst-2 - Fastest analysis added in 0.8740501403808594 seconds
# Analyst-2 - Slowest analysis added in 2.3091320991516113 seconds
# Analyst-2 - Average time adding analysis: 1.6095921397209167 seconds
# Analyst-3 - Fastest acquisition gotten in 0.22701287269592285 seconds
# Analyst-3 - Slowest acquisition gotten in 0.8830504417419434 seconds
# Analyst-3 - Average time getting acquisitions: 0.448275625705719 seconds
# Analyst-3 - Fastest analysis added in 2.0891194343566895 seconds
# Analyst-3 - Slowest analysis added in 2.374135732650757 seconds
# Analyst-3 - Average time adding analysis: 2.286130726337433 seconds
# Analyst-4 - Fastest acquisition gotten in 0.13600778579711914 seconds
# Analyst-4 - Slowest acquisition gotten in 1.1630666255950928 seconds
# Analyst-4 - Average time getting acquisitions: 0.4475255608558655 seconds
# Analyst-4 - Fastest analysis added in 0.4980282783508301 seconds
# Analyst-4 - Slowest analysis added in 2.414138078689575 seconds
# Analyst-4 - Average time adding analysis: 1.800352931022644 seconds
# Analyst-5 - Fastest acquisition gotten in 0.18001055717468262 seconds
# Analyst-5 - Slowest acquisition gotten in 1.0860621929168701 seconds
# Analyst-5 - Average time getting acquisitions: 0.4585263133049011 seconds
# Analyst-5 - Fastest analysis added in 1.3950798511505127 seconds
# Analyst-5 - Slowest analysis added in 2.4641408920288086 seconds
# Analyst-5 - Average time adding analysis: 1.856106162071228 seconds
# Analyst-6 - Fastest acquisition gotten in 0.14000797271728516 seconds
# Analyst-6 - Slowest acquisition gotten in 1.073061466217041 seconds
# Analyst-6 - Average time getting acquisitions: 0.4975285530090332 seconds
# Analyst-6 - Fastest analysis added in 2.3221328258514404 seconds
# Analyst-6 - Slowest analysis added in 2.6711525917053223 seconds
# Analyst-6 - Average time adding analysis: 2.480641782283783 seconds
# Analyst-7 - Fastest acquisition gotten in 0.15100884437561035 seconds
# Analyst-7 - Slowest acquisition gotten in 1.0920624732971191 seconds
# Analyst-7 - Average time getting acquisitions: 0.42952460050582886 seconds
# Analyst-7 - Fastest analysis added in 1.6100924015045166 seconds
# Analyst-7 - Slowest analysis added in 2.4571404457092285 seconds
# Analyst-7 - Average time adding analysis: 2.206626236438751 seconds
# Analyst-8 - Fastest acquisition gotten in 0.21801233291625977 seconds
# Analyst-8 - Slowest acquisition gotten in 1.1520657539367676 seconds
# Analyst-8 - Average time getting acquisitions: 0.4855276942253113 seconds
# Analyst-8 - Fastest analysis added in 0.9590549468994141 seconds
# Analyst-8 - Slowest analysis added in 2.5761475563049316 seconds
# Analyst-8 - Average time adding analysis: 1.7871022820472717 seconds
# Analyst-9 - Fastest acquisition gotten in 0.12700700759887695 seconds
# Analyst-9 - Slowest acquisition gotten in 1.1410651206970215 seconds
# Analyst-9 - Average time getting acquisitions: 0.4160236716270447 seconds
# Analyst-9 - Fastest analysis added in 2.3281331062316895 seconds
# Analyst-9 - Slowest analysis added in 2.6911540031433105 seconds
# Analyst-9 - Average time adding analysis: 2.430889070034027 seconds
# Analyst-10 - Fastest acquisition gotten in 0.18001055717468262 seconds
# Analyst-10 - Slowest acquisition gotten in 1.0470600128173828 seconds
# Analyst-10 - Average time getting acquisitions: 0.4625266194343567 seconds
# Analyst-10 - Fastest analysis added in 1.8111035823822021 seconds
# Analyst-10 - Slowest analysis added in 2.4481399059295654 seconds
# Analyst-10 - Average time adding analysis: 2.181124746799469 seconds
# Analyst-11 - Fastest acquisition gotten in 0.2830162048339844 seconds
# Analyst-11 - Slowest acquisition gotten in 1.069061040878296 seconds
# Analyst-11 - Average time getting acquisitions: 0.5405308604240417 seconds
# Analyst-11 - Fastest analysis added in 0.5360307693481445 seconds
# Analyst-11 - Slowest analysis added in 1.4100806713104248 seconds
# Analyst-11 - Average time adding analysis: 0.9215526580810547 seconds
# Analyst-12 - Fastest acquisition gotten in 0.17500972747802734 seconds
# Analyst-12 - Slowest acquisition gotten in 1.1030631065368652 seconds
# Analyst-12 - Average time getting acquisitions: 0.4955282211303711 seconds
# Analyst-12 - Fastest analysis added in 1.5050861835479736 seconds
# Analyst-12 - Slowest analysis added in 2.5771472454071045 seconds
# Analyst-12 - Average time adding analysis: 2.201875925064087 seconds
# Analyst-13 - Fastest acquisition gotten in 0.1260073184967041 seconds
# Analyst-13 - Slowest acquisition gotten in 1.1090633869171143 seconds
# Analyst-13 - Average time getting acquisitions: 0.4692767858505249 seconds
# Analyst-13 - Fastest analysis added in 0.5300302505493164 seconds
# Analyst-13 - Slowest analysis added in 2.3061320781707764 seconds
# Analyst-13 - Average time adding analysis: 1.4628337025642395 seconds
# Analyst-14 - Fastest acquisition gotten in 0.13100743293762207 seconds
# Analyst-14 - Slowest acquisition gotten in 1.0990629196166992 seconds
# Analyst-14 - Average time getting acquisitions: 0.41952407360076904 seconds
# Analyst-14 - Fastest analysis added in 1.3110747337341309 seconds
# Analyst-14 - Slowest analysis added in 2.39613676071167 seconds
# Analyst-14 - Average time adding analysis: 1.853355884552002 seconds
# Analyst-15 - Fastest acquisition gotten in 0.1260073184967041 seconds
# Analyst-15 - Slowest acquisition gotten in 1.1650664806365967 seconds
# Analyst-15 - Average time getting acquisitions: 0.49227821826934814 seconds
# Analyst-15 - Fastest analysis added in 0.5040285587310791 seconds
# Analyst-15 - Slowest analysis added in 2.3221325874328613 seconds
# Analyst-15 - Average time adding analysis: 1.6383435130119324 seconds
# Analyst-16 - Fastest acquisition gotten in 0.17301011085510254 seconds
# Analyst-16 - Slowest acquisition gotten in 1.1550662517547607 seconds
# Analyst-16 - Average time getting acquisitions: 0.47752732038497925 seconds
# Analyst-16 - Fastest analysis added in 0.6770386695861816 seconds
# Analyst-16 - Slowest analysis added in 2.3221325874328613 seconds
# Analyst-16 - Average time adding analysis: 1.3105749487876892 seconds
# Analyst-17 - Fastest acquisition gotten in 0.17000961303710938 seconds
# Analyst-17 - Slowest acquisition gotten in 1.084061861038208 seconds
# Analyst-17 - Average time getting acquisitions: 0.4930281639099121 seconds
# Analyst-17 - Fastest analysis added in 0.955054521560669 seconds
# Analyst-17 - Slowest analysis added in 2.63615083694458 seconds
# Analyst-17 - Average time adding analysis: 1.7493500113487244 seconds
# Analyst-18 - Fastest acquisition gotten in 0.16700959205627441 seconds
# Analyst-18 - Slowest acquisition gotten in 1.1260643005371094 seconds
# Analyst-18 - Average time getting acquisitions: 0.4570261836051941 seconds
# Analyst-18 - Fastest analysis added in 0.37902164459228516 seconds
# Analyst-18 - Slowest analysis added in 2.406137466430664 seconds
# Analyst-18 - Average time adding analysis: 1.3288258910179138 seconds
# Analyst-19 - Fastest acquisition gotten in 0.14000797271728516 seconds
# Analyst-19 - Slowest acquisition gotten in 1.067060947418213 seconds
# Analyst-19 - Average time getting acquisitions: 0.444275438785553 seconds
# Analyst-19 - Fastest analysis added in 0.5650324821472168 seconds
# Analyst-19 - Slowest analysis added in 2.3481342792510986 seconds
# Analyst-19 - Average time adding analysis: 1.816853940486908 seconds
# Analyst-20 - Fastest acquisition gotten in 0.17200970649719238 seconds
# Analyst-20 - Slowest acquisition gotten in 1.1200640201568604 seconds
# Analyst-20 - Average time getting acquisitions: 0.4710268974304199 seconds
# Analyst-20 - Fastest analysis added in 0.5030286312103271 seconds
# Analyst-20 - Slowest analysis added in 2.536144971847534 seconds
# Analyst-20 - Average time adding analysis: 1.987863540649414 seconds
# Analyst-21 - Fastest acquisition gotten in 0.18101048469543457 seconds
# Analyst-21 - Slowest acquisition gotten in 1.1020631790161133 seconds
# Analyst-21 - Average time getting acquisitions: 0.46152645349502563 seconds
# Analyst-21 - Fastest analysis added in 1.5350878238677979 seconds
# Analyst-21 - Slowest analysis added in 2.6711528301239014 seconds
# Analyst-21 - Average time adding analysis: 2.269129753112793 seconds
# Analyst-22 - Fastest acquisition gotten in 0.13000726699829102 seconds
# Analyst-22 - Slowest acquisition gotten in 1.1110634803771973 seconds
# Analyst-22 - Average time getting acquisitions: 0.4217740297317505 seconds
# Analyst-22 - Fastest analysis added in 1.0610606670379639 seconds
# Analyst-22 - Slowest analysis added in 2.486142158508301 seconds
# Analyst-22 - Average time adding analysis: 2.0591177940368652 seconds
# Analyst-23 - Fastest acquisition gotten in 0.12200713157653809 seconds
# Analyst-23 - Slowest acquisition gotten in 1.1010630130767822 seconds
# Analyst-23 - Average time getting acquisitions: 0.4350249171257019 seconds
# Analyst-23 - Fastest analysis added in 1.4570834636688232 seconds
# Analyst-23 - Slowest analysis added in 2.360135078430176 seconds
# Analyst-23 - Average time adding analysis: 1.9991143345832825 seconds
# Analyst-24 - Fastest acquisition gotten in 0.19701147079467773 seconds
# Analyst-24 - Slowest acquisition gotten in 1.0920624732971191 seconds
# Analyst-24 - Average time getting acquisitions: 0.4595264196395874 seconds
# Analyst-24 - Fastest analysis added in 2.3291332721710205 seconds
# Analyst-24 - Slowest analysis added in 2.6611521244049072 seconds
# Analyst-24 - Average time adding analysis: 2.5298946499824524 seconds
# MIN GET ACQ --> 0.12200713157653809
# AVG GET ACQ --> 0.4663166689872742
# MAX GET ACQ --> 1.1650664806365967
# MIN ADD ANA --> 0.37902164459228516
# AVG ADD ANA --> 1.9024087858200074
# MAX ADD ANA --> 2.418138265609741
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with fifty (50) analysts

# %%
addAnalysisTest(50, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has startedAnalyst Analyst-2 has started
#
# Analyst Analyst-3 has startedAnalyst Analyst-4 has startedAnalyst Analyst-5 has started
#
# Analyst Analyst-6 has started
#
# Analyst Analyst-7 has started
# Analyst Analyst-8 has started
# Analyst Analyst-9 has startedAnalyst Analyst-10 has started
#
# Analyst Analyst-11 has startedAnalyst Analyst-12 has started
#
# Analyst Analyst-13 has started
# Analyst Analyst-14 has started
# Analyst Analyst-15 has started
# Analyst Analyst-16 has startedAnalyst Analyst-17 has started
# Analyst Analyst-18 has started
#
# Analyst Analyst-19 has started
# Analyst Analyst-20 has started
# Analyst Analyst-21 has startedAnalyst Analyst-22 has started
#
# Analyst Analyst-23 has started
# Analyst Analyst-24 has started
# Analyst Analyst-25 has started
# Analyst Analyst-26 has started
# Analyst Analyst-27 has started
# Analyst Analyst-28 has startedAnalyst Analyst-29 has started
# Analyst Analyst-30 has started
#
# Analyst Analyst-31 has started
# Analyst Analyst-32 has started
# Analyst Analyst-33 has started
# Analyst Analyst-34 has started
# Analyst Analyst-35 has started
# Analyst Analyst-36 has started
# Analyst Analyst-37 has started
# Analyst Analyst-38 has started
# Analyst Analyst-39 has started
# Analyst Analyst-40 has started
# Analyst Analyst-41 has startedAnalyst Analyst-42 has started
# Analyst Analyst-43 has started
#
# Analyst Analyst-44 has started
# Analyst Analyst-45 has started
# Analyst Analyst-46 has started
# Analyst Analyst-47 has startedAnalyst Analyst-48 has started
#
# Analyst Analyst-49 has started
# Analyst Analyst-2 has finishedAnalyst Analyst-0 has finished
#
# Analyst Analyst-46 has finishedAnalyst Analyst-47 has finished
#
# Analyst Analyst-7 has finished
# Analyst Analyst-27 has finished
# Analyst Analyst-28 has finished
# Analyst Analyst-14 has finished
# Analyst Analyst-38 has finished
# Analyst Analyst-30 has finished
# Analyst Analyst-40 has finishedAnalyst Analyst-4 has finished
#
# Analyst Analyst-37 has finished
# Analyst Analyst-43 has finished
# Analyst Analyst-20 has finished
# Analyst Analyst-21 has finishedAnalyst Analyst-23 has finished
# Analyst Analyst-9 has finished
#
# Analyst Analyst-26 has finishedAnalyst Analyst-25 has finishedAnalyst Analyst-32 has finished
#
#
# Analyst Analyst-18 has finished
# Analyst Analyst-49 has finishedAnalyst Analyst-44 has finishedAnalyst Analyst-34 has finished
#
#
# Analyst Analyst-29 has finished
# Analyst Analyst-13 has finishedAnalyst Analyst-35 has finishedAnalyst Analyst-42 has finished
# Analyst Analyst-41 has finished
#
#
# Analyst Analyst-8 has finished
# Analyst Analyst-3 has finished
# Analyst Analyst-16 has finishedAnalyst Analyst-22 has finished
#
# Analyst Analyst-17 has finished
# Analyst Analyst-12 has finished
# Analyst Analyst-6 has finishedAnalyst Analyst-39 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-15 has finished
#
# Analyst Analyst-10 has finished
# Analyst Analyst-24 has finishedAnalyst Analyst-5 has finished
#
# Analyst Analyst-31 has finished
# Analyst Analyst-36 has finished
# Analyst Analyst-48 has finishedAnalyst Analyst-11 has finished
#
# Analyst Analyst-33 has finishedAnalyst Analyst-19 has finished
#
# Analyst Analyst-45 has finished
# Analyst-0 - Fastest acquisition gotten in 0.27701592445373535 seconds
# Analyst-0 - Slowest acquisition gotten in 1.783102035522461 seconds
# Analyst-0 - Average time getting acquisitions: 1.0300589799880981 seconds
# Analyst-0 - Fastest analysis added in 1.3770787715911865 seconds
# Analyst-0 - Slowest analysis added in 2.4431397914886475 seconds
# Analyst-0 - Average time adding analysis: 1.910109281539917 seconds
# Analyst-1 - Fastest acquisition gotten in 0.2040119171142578 seconds
# Analyst-1 - Slowest acquisition gotten in 1.7481000423431396 seconds
# Analyst-1 - Average time getting acquisitions: 0.9760559797286987 seconds
# Analyst-1 - Fastest analysis added in 1.7611007690429688 seconds
# Analyst-1 - Slowest analysis added in 2.876164197921753 seconds
# Analyst-1 - Average time adding analysis: 2.318632483482361 seconds
# Analyst-2 - Fastest acquisition gotten in 0.27301573753356934 seconds
# Analyst-2 - Slowest acquisition gotten in 1.699096918106079 seconds
# Analyst-2 - Average time getting acquisitions: 0.9860563278198242 seconds
# Analyst-2 - Fastest analysis added in 2.4381394386291504 seconds
# Analyst-2 - Slowest analysis added in 2.4481401443481445 seconds
# Analyst-2 - Average time adding analysis: 2.4431397914886475 seconds
# Analyst-3 - Fastest acquisition gotten in 0.343019962310791 seconds
# Analyst-3 - Slowest acquisition gotten in 1.681095838546753 seconds
# Analyst-3 - Average time getting acquisitions: 1.012057900428772 seconds
# Analyst-3 - Fastest analysis added in 2.299131393432617 seconds
# Analyst-3 - Slowest analysis added in 2.3651351928710938 seconds
# Analyst-3 - Average time adding analysis: 2.3321332931518555 seconds
# Analyst-4 - Fastest acquisition gotten in 0.4930284023284912 seconds
# Analyst-4 - Slowest acquisition gotten in 1.4170811176300049 seconds
# Analyst-4 - Average time getting acquisitions: 0.955054759979248 seconds
# Analyst-4 - Fastest analysis added in 0.715040922164917 seconds
# Analyst-4 - Slowest analysis added in 1.5010857582092285 seconds
# Analyst-4 - Average time adding analysis: 1.1080633401870728 seconds
# Analyst-5 - Fastest acquisition gotten in 0.3020172119140625 seconds
# Analyst-5 - Slowest acquisition gotten in 1.7040975093841553 seconds
# Analyst-5 - Average time getting acquisitions: 1.0030573606491089 seconds
# Analyst-5 - Fastest analysis added in 0.6850390434265137 seconds
# Analyst-5 - Slowest analysis added in 1.456083059310913 seconds
# Analyst-5 - Average time adding analysis: 1.0705610513687134 seconds
# Analyst-6 - Fastest acquisition gotten in 0.22701334953308105 seconds
# Analyst-6 - Slowest acquisition gotten in 1.6990971565246582 seconds
# Analyst-6 - Average time getting acquisitions: 0.9630552530288696 seconds
# Analyst-6 - Fastest analysis added in 2.735156297683716 seconds
# Analyst-6 - Slowest analysis added in 2.881164789199829 seconds
# Analyst-6 - Average time adding analysis: 2.8081605434417725 seconds
# Analyst-7 - Fastest acquisition gotten in 0.4760274887084961 seconds
# Analyst-7 - Slowest acquisition gotten in 1.6490943431854248 seconds
# Analyst-7 - Average time getting acquisitions: 1.0625609159469604 seconds
# Analyst-7 - Fastest analysis added in 2.2961313724517822 seconds
# Analyst-7 - Slowest analysis added in 2.4241385459899902 seconds
# Analyst-7 - Average time adding analysis: 2.3601349592208862 seconds
# Analyst-8 - Fastest acquisition gotten in 0.28101611137390137 seconds
# Analyst-8 - Slowest acquisition gotten in 1.3790786266326904 seconds
# Analyst-8 - Average time getting acquisitions: 0.8300473690032959 seconds
# Analyst-8 - Fastest analysis added in 1.5120863914489746 seconds
# Analyst-8 - Slowest analysis added in 2.4711413383483887 seconds
# Analyst-8 - Average time adding analysis: 1.9916138648986816 seconds
# Analyst-9 - Fastest acquisition gotten in 0.33801960945129395 seconds
# Analyst-9 - Slowest acquisition gotten in 1.6370935440063477 seconds
# Analyst-9 - Average time getting acquisitions: 0.9875565767288208 seconds
# Analyst-9 - Fastest analysis added in 1.3410768508911133 seconds
# Analyst-9 - Slowest analysis added in 1.6460943222045898 seconds
# Analyst-9 - Average time adding analysis: 1.4935855865478516 seconds
# Analyst-10 - Fastest acquisition gotten in 0.35502028465270996 seconds
# Analyst-10 - Slowest acquisition gotten in 1.6570947170257568 seconds
# Analyst-10 - Average time getting acquisitions: 1.0060575008392334 seconds
# Analyst-10 - Fastest analysis added in 1.651094675064087 seconds
# Analyst-10 - Slowest analysis added in 1.8171038627624512 seconds
# Analyst-10 - Average time adding analysis: 1.734099268913269 seconds
# Analyst-11 - Fastest acquisition gotten in 0.15800905227661133 seconds
# Analyst-11 - Slowest acquisition gotten in 1.328075885772705 seconds
# Analyst-11 - Average time getting acquisitions: 0.7430424690246582 seconds
# Analyst-11 - Fastest analysis added in 1.6970973014831543 seconds
# Analyst-11 - Slowest analysis added in 2.048117160797119 seconds
# Analyst-11 - Average time adding analysis: 1.8726072311401367 seconds
# Analyst-12 - Fastest acquisition gotten in 0.22001242637634277 seconds
# Analyst-12 - Slowest acquisition gotten in 1.6330933570861816 seconds
# Analyst-12 - Average time getting acquisitions: 0.9265528917312622 seconds
# Analyst-12 - Fastest analysis added in 2.716155529022217 seconds
# Analyst-12 - Slowest analysis added in 2.857163667678833 seconds
# Analyst-12 - Average time adding analysis: 2.786659598350525 seconds
# Analyst-13 - Fastest acquisition gotten in 0.3210184574127197 seconds
# Analyst-13 - Slowest acquisition gotten in 1.7711009979248047 seconds
# Analyst-13 - Average time getting acquisitions: 1.0460597276687622 seconds
# Analyst-13 - Fastest analysis added in 1.0110578536987305 seconds
# Analyst-13 - Slowest analysis added in 2.4671411514282227 seconds
# Analyst-13 - Average time adding analysis: 1.7390995025634766 seconds
# Analyst-14 - Fastest acquisition gotten in 0.3210184574127197 seconds
# Analyst-14 - Slowest acquisition gotten in 1.6610949039459229 seconds
# Analyst-14 - Average time getting acquisitions: 0.9910566806793213 seconds
# Analyst-14 - Fastest analysis added in 1.1110634803771973 seconds
# Analyst-14 - Slowest analysis added in 1.8781075477600098 seconds
# Analyst-14 - Average time adding analysis: 1.4945855140686035 seconds
# Analyst-15 - Fastest acquisition gotten in 0.2800159454345703 seconds
# Analyst-15 - Slowest acquisition gotten in 1.651094675064087 seconds
# Analyst-15 - Average time getting acquisitions: 0.9655553102493286 seconds
# Analyst-15 - Fastest analysis added in 1.3750786781311035 seconds
# Analyst-15 - Slowest analysis added in 2.1001200675964355 seconds
# Analyst-15 - Average time adding analysis: 1.7375993728637695 seconds
# Analyst-16 - Fastest acquisition gotten in 0.23301315307617188 seconds
# Analyst-16 - Slowest acquisition gotten in 1.804103136062622 seconds
# Analyst-16 - Average time getting acquisitions: 1.018558144569397 seconds
# Analyst-16 - Fastest analysis added in 2.3281331062316895 seconds
# Analyst-16 - Slowest analysis added in 2.528144598007202 seconds
# Analyst-16 - Average time adding analysis: 2.428138852119446 seconds
# Analyst-17 - Fastest acquisition gotten in 0.34201931953430176 seconds
# Analyst-17 - Slowest acquisition gotten in 1.7370996475219727 seconds
# Analyst-17 - Average time getting acquisitions: 1.0395594835281372 seconds
# Analyst-17 - Fastest analysis added in 0.6390366554260254 seconds
# Analyst-17 - Slowest analysis added in 1.171067237854004 seconds
# Analyst-17 - Average time adding analysis: 0.9050519466400146 seconds
# Analyst-18 - Fastest acquisition gotten in 0.30701756477355957 seconds
# Analyst-18 - Slowest acquisition gotten in 1.6210927963256836 seconds
# Analyst-18 - Average time getting acquisitions: 0.9640551805496216 seconds
# Analyst-18 - Fastest analysis added in 0.41402363777160645 seconds
# Analyst-18 - Slowest analysis added in 1.5900909900665283 seconds
# Analyst-18 - Average time adding analysis: 1.0020573139190674 seconds
# Analyst-19 - Fastest acquisition gotten in 0.2700154781341553 seconds
# Analyst-19 - Slowest acquisition gotten in 1.7731013298034668 seconds
# Analyst-19 - Average time getting acquisitions: 1.021558403968811 seconds
# Analyst-19 - Fastest analysis added in 2.3011314868927 seconds
# Analyst-19 - Slowest analysis added in 2.635150909423828 seconds
# Analyst-19 - Average time adding analysis: 2.468141198158264 seconds
# Analyst-20 - Fastest acquisition gotten in 0.5050287246704102 seconds
# Analyst-20 - Slowest acquisition gotten in 1.7430999279022217 seconds
# Analyst-20 - Average time getting acquisitions: 1.124064326286316 seconds
# Analyst-20 - Fastest analysis added in 1.196068525314331 seconds
# Analyst-20 - Slowest analysis added in 1.545088291168213 seconds
# Analyst-20 - Average time adding analysis: 1.370578408241272 seconds
# Analyst-21 - Fastest acquisition gotten in 0.5280303955078125 seconds
# Analyst-21 - Slowest acquisition gotten in 1.6970973014831543 seconds
# Analyst-21 - Average time getting acquisitions: 1.1125638484954834 seconds
# Analyst-21 - Fastest analysis added in 2.2131266593933105 seconds
# Analyst-21 - Slowest analysis added in 2.405137300491333 seconds
# Analyst-21 - Average time adding analysis: 2.3091319799423218 seconds
# Analyst-22 - Fastest acquisition gotten in 0.3190183639526367 seconds
# Analyst-22 - Slowest acquisition gotten in 1.7040975093841553 seconds
# Analyst-22 - Average time getting acquisitions: 1.011557936668396 seconds
# Analyst-22 - Fastest analysis added in 1.192068099975586 seconds
# Analyst-22 - Slowest analysis added in 2.641150951385498 seconds
# Analyst-22 - Average time adding analysis: 1.916609525680542 seconds
# Analyst-23 - Fastest acquisition gotten in 0.2110121250152588 seconds
# Analyst-23 - Slowest acquisition gotten in 1.7591006755828857 seconds
# Analyst-23 - Average time getting acquisitions: 0.9850564002990723 seconds
# Analyst-23 - Fastest analysis added in 1.3730783462524414 seconds
# Analyst-23 - Slowest analysis added in 2.493142604827881 seconds
# Analyst-23 - Average time adding analysis: 1.9331104755401611 seconds
# Analyst-24 - Fastest acquisition gotten in 0.2740156650543213 seconds
# Analyst-24 - Slowest acquisition gotten in 1.669095516204834 seconds
# Analyst-24 - Average time getting acquisitions: 0.9715555906295776 seconds
# Analyst-24 - Fastest analysis added in 2.3251326084136963 seconds
# Analyst-24 - Slowest analysis added in 2.660151958465576 seconds
# Analyst-24 - Average time adding analysis: 2.4926422834396362 seconds
# Analyst-25 - Fastest acquisition gotten in 0.1500086784362793 seconds
# Analyst-25 - Slowest acquisition gotten in 1.664095163345337 seconds
# Analyst-25 - Average time getting acquisitions: 0.9070519208908081 seconds
# Analyst-25 - Fastest analysis added in 0.47502708435058594 seconds
# Analyst-25 - Slowest analysis added in 2.5941483974456787 seconds
# Analyst-25 - Average time adding analysis: 1.5345877408981323 seconds
# Analyst-26 - Fastest acquisition gotten in 0.27901601791381836 seconds
# Analyst-26 - Slowest acquisition gotten in 1.7350993156433105 seconds
# Analyst-26 - Average time getting acquisitions: 1.0070576667785645 seconds
# Analyst-26 - Fastest analysis added in 0.4320247173309326 seconds
# Analyst-26 - Slowest analysis added in 1.435081958770752 seconds
# Analyst-26 - Average time adding analysis: 0.9335533380508423 seconds
# Analyst-27 - Fastest acquisition gotten in 0.5040290355682373 seconds
# Analyst-27 - Slowest acquisition gotten in 1.7751014232635498 seconds
# Analyst-27 - Average time getting acquisitions: 1.1395652294158936 seconds
# Analyst-27 - Fastest analysis added in 2.1111204624176025 seconds
# Analyst-27 - Slowest analysis added in 2.4701411724090576 seconds
# Analyst-27 - Average time adding analysis: 2.29063081741333 seconds
# Analyst-28 - Fastest acquisition gotten in 0.5130293369293213 seconds
# Analyst-28 - Slowest acquisition gotten in 1.7821016311645508 seconds
# Analyst-28 - Average time getting acquisitions: 1.147565484046936 seconds
# Analyst-28 - Fastest analysis added in 2.1061203479766846 seconds
# Analyst-28 - Slowest analysis added in 2.4651410579681396 seconds
# Analyst-28 - Average time adding analysis: 2.285630702972412 seconds
# Analyst-29 - Fastest acquisition gotten in 0.33801937103271484 seconds
# Analyst-29 - Slowest acquisition gotten in 1.7601006031036377 seconds
# Analyst-29 - Average time getting acquisitions: 1.0490599870681763 seconds
# Analyst-29 - Fastest analysis added in 2.3031318187713623 seconds
# Analyst-29 - Slowest analysis added in 2.5481455326080322 seconds
# Analyst-29 - Average time adding analysis: 2.4256386756896973 seconds
# Analyst-30 - Fastest acquisition gotten in 0.3450198173522949 seconds
# Analyst-30 - Slowest acquisition gotten in 1.7661008834838867 seconds
# Analyst-30 - Average time getting acquisitions: 1.0555603504180908 seconds
# Analyst-30 - Fastest analysis added in 0.5490312576293945 seconds
# Analyst-30 - Slowest analysis added in 2.052117109298706 seconds
# Analyst-30 - Average time adding analysis: 1.3005741834640503 seconds
# Analyst-31 - Fastest acquisition gotten in 0.21801233291625977 seconds
# Analyst-31 - Slowest acquisition gotten in 1.7801017761230469 seconds
# Analyst-31 - Average time getting acquisitions: 0.9990570545196533 seconds
# Analyst-31 - Fastest analysis added in 2.3221330642700195 seconds
# Analyst-31 - Slowest analysis added in 2.4371395111083984 seconds
# Analyst-31 - Average time adding analysis: 2.379636287689209 seconds
# Analyst-32 - Fastest acquisition gotten in 0.22901296615600586 seconds
# Analyst-32 - Slowest acquisition gotten in 1.6610949039459229 seconds
# Analyst-32 - Average time getting acquisitions: 0.9450539350509644 seconds
# Analyst-32 - Fastest analysis added in 1.5860908031463623 seconds
# Analyst-32 - Slowest analysis added in 2.376136064529419 seconds
# Analyst-32 - Average time adding analysis: 1.9811134338378906 seconds
# Analyst-33 - Fastest acquisition gotten in 0.21001219749450684 seconds
# Analyst-33 - Slowest acquisition gotten in 1.7390995025634766 seconds
# Analyst-33 - Average time getting acquisitions: 0.9745558500289917 seconds
# Analyst-33 - Fastest analysis added in 0.358020544052124 seconds
# Analyst-33 - Slowest analysis added in 1.5990915298461914 seconds
# Analyst-33 - Average time adding analysis: 0.9785560369491577 seconds
# Analyst-34 - Fastest acquisition gotten in 0.3080177307128906 seconds
# Analyst-34 - Slowest acquisition gotten in 1.80910325050354 seconds
# Analyst-34 - Average time getting acquisitions: 1.0585604906082153 seconds
# Analyst-34 - Fastest analysis added in 1.31107497215271 seconds
# Analyst-34 - Slowest analysis added in 1.4730842113494873 seconds
# Analyst-34 - Average time adding analysis: 1.3920795917510986 seconds
# Analyst-35 - Fastest acquisition gotten in 0.4650266170501709 seconds
# Analyst-35 - Slowest acquisition gotten in 1.7460999488830566 seconds
# Analyst-35 - Average time getting acquisitions: 1.1055632829666138 seconds
# Analyst-35 - Fastest analysis added in 1.1140637397766113 seconds
# Analyst-35 - Slowest analysis added in 2.1031203269958496 seconds
# Analyst-35 - Average time adding analysis: 1.6085920333862305 seconds
# Analyst-36 - Fastest acquisition gotten in 0.2580146789550781 seconds
# Analyst-36 - Slowest acquisition gotten in 1.7440998554229736 seconds
# Analyst-36 - Average time getting acquisitions: 1.0010572671890259 seconds
# Analyst-36 - Fastest analysis added in 2.4681410789489746 seconds
# Analyst-36 - Slowest analysis added in 2.5791475772857666 seconds
# Analyst-36 - Average time adding analysis: 2.5236443281173706 seconds
# Analyst-37 - Fastest acquisition gotten in 0.2670152187347412 seconds
# Analyst-37 - Slowest acquisition gotten in 1.7711012363433838 seconds
# Analyst-37 - Average time getting acquisitions: 1.0190582275390625 seconds
# Analyst-37 - Fastest analysis added in 1.3350763320922852 seconds
# Analyst-37 - Slowest analysis added in 2.520144462585449 seconds
# Analyst-37 - Average time adding analysis: 1.9276103973388672 seconds
# Analyst-38 - Fastest acquisition gotten in 0.5150294303894043 seconds
# Analyst-38 - Slowest acquisition gotten in 1.792102336883545 seconds
# Analyst-38 - Average time getting acquisitions: 1.1535658836364746 seconds
# Analyst-38 - Fastest analysis added in 1.056060552597046 seconds
# Analyst-38 - Slowest analysis added in 2.305131673812866 seconds
# Analyst-38 - Average time adding analysis: 1.680596113204956 seconds
# Analyst-39 - Fastest acquisition gotten in 0.2700154781341553 seconds
# Analyst-39 - Slowest acquisition gotten in 1.781101942062378 seconds
# Analyst-39 - Average time getting acquisitions: 1.0255587100982666 seconds
# Analyst-39 - Fastest analysis added in 1.5320875644683838 seconds
# Analyst-39 - Slowest analysis added in 2.6841535568237305 seconds
# Analyst-39 - Average time adding analysis: 2.108120560646057 seconds
# Analyst-40 - Fastest acquisition gotten in 0.19201087951660156 seconds
# Analyst-40 - Slowest acquisition gotten in 1.7350993156433105 seconds
# Analyst-40 - Average time getting acquisitions: 0.963555097579956 seconds
# Analyst-40 - Fastest analysis added in 0.43102478981018066 seconds
# Analyst-40 - Slowest analysis added in 2.4691412448883057 seconds
# Analyst-40 - Average time adding analysis: 1.4500830173492432 seconds
# Analyst-41 - Fastest acquisition gotten in 0.3320188522338867 seconds
# Analyst-41 - Slowest acquisition gotten in 1.7430999279022217 seconds
# Analyst-41 - Average time getting acquisitions: 1.0375593900680542 seconds
# Analyst-41 - Fastest analysis added in 1.4620838165283203 seconds
# Analyst-41 - Slowest analysis added in 1.8561062812805176 seconds
# Analyst-41 - Average time adding analysis: 1.659095048904419 seconds
# Analyst-42 - Fastest acquisition gotten in 0.2670152187347412 seconds
# Analyst-42 - Slowest acquisition gotten in 1.7571003437042236 seconds
# Analyst-42 - Average time getting acquisitions: 1.0120577812194824 seconds
# Analyst-42 - Fastest analysis added in 1.8281044960021973 seconds
# Analyst-42 - Slowest analysis added in 2.535144805908203 seconds
# Analyst-42 - Average time adding analysis: 2.1816246509552 seconds
# Analyst-43 - Fastest acquisition gotten in 0.3000171184539795 seconds
# Analyst-43 - Slowest acquisition gotten in 1.7190985679626465 seconds
# Analyst-43 - Average time getting acquisitions: 1.009557843208313 seconds
# Analyst-43 - Fastest analysis added in 2.362135171890259 seconds
# Analyst-43 - Slowest analysis added in 2.489142417907715 seconds
# Analyst-43 - Average time adding analysis: 2.425638794898987 seconds
# Analyst-44 - Fastest acquisition gotten in 0.46202659606933594 seconds
# Analyst-44 - Slowest acquisition gotten in 1.7110977172851562 seconds
# Analyst-44 - Average time getting acquisitions: 1.086562156677246 seconds
# Analyst-44 - Fastest analysis added in 1.5840904712677002 seconds
# Analyst-44 - Slowest analysis added in 2.1031200885772705 seconds
# Analyst-44 - Average time adding analysis: 1.8436052799224854 seconds
# Analyst-45 - Fastest acquisition gotten in 0.13300752639770508 seconds
# Analyst-45 - Slowest acquisition gotten in 1.7350990772247314 seconds
# Analyst-45 - Average time getting acquisitions: 0.9340533018112183 seconds
# Analyst-45 - Fastest analysis added in 2.3061318397521973 seconds
# Analyst-45 - Slowest analysis added in 2.3101320266723633 seconds
# Analyst-45 - Average time adding analysis: 2.3081319332122803 seconds
# Analyst-46 - Fastest acquisition gotten in 0.1630096435546875 seconds
# Analyst-46 - Slowest acquisition gotten in 1.7380990982055664 seconds
# Analyst-46 - Average time getting acquisitions: 0.950554370880127 seconds
# Analyst-46 - Fastest analysis added in 2.3141324520111084 seconds
# Analyst-46 - Slowest analysis added in 2.496142625808716 seconds
# Analyst-46 - Average time adding analysis: 2.405137538909912 seconds
# Analyst-47 - Fastest acquisition gotten in 0.16000914573669434 seconds
# Analyst-47 - Slowest acquisition gotten in 1.7070977687835693 seconds
# Analyst-47 - Average time getting acquisitions: 0.9335534572601318 seconds
# Analyst-47 - Fastest analysis added in 1.31807541847229 seconds
# Analyst-47 - Slowest analysis added in 2.516143798828125 seconds
# Analyst-47 - Average time adding analysis: 1.9171096086502075 seconds
# Analyst-48 - Fastest acquisition gotten in 0.27301573753356934 seconds
# Analyst-48 - Slowest acquisition gotten in 1.7250988483428955 seconds
# Analyst-48 - Average time getting acquisitions: 0.9990572929382324 seconds
# Analyst-48 - Fastest analysis added in 1.4610836505889893 seconds
# Analyst-48 - Slowest analysis added in 1.545088291168213 seconds
# Analyst-48 - Average time adding analysis: 1.503085970878601 seconds
# Analyst-49 - Fastest acquisition gotten in 0.22101259231567383 seconds
# Analyst-49 - Slowest acquisition gotten in 1.7060976028442383 seconds
# Analyst-49 - Average time getting acquisitions: 0.963555097579956 seconds
# Analyst-49 - Fastest analysis added in 0.459026575088501 seconds
# Analyst-49 - Slowest analysis added in 2.4461398124694824 seconds
# Analyst-49 - Average time adding analysis: 1.4525831937789917 seconds
# MIN GET ACQ --> 0.13300752639770508
# AVG GET ACQ --> 1.0042074489593507
# MAX GET ACQ --> 1.80910325050354
# MIN ADD ANA --> 0.358020544052124
# AVG ADD ANA --> 1.8904581189155578
# MAX ADD ANA --> 2.4431397914886475
# Add Analysis Test Finalized

# %% [markdown]
# ### Activating Plotly (scientific graphing library)

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Charts

# %%
num_analysts = ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"]

min_get_acq = [0.12400674819946289, 0.12300705909729004, 0.12300682067871094, 0.1240072250366211, 0.12200713157653809, 0.13300752639770508]
avg_get_acq = [0.14027803659439086, 0.14551831007003785, 0.1644293904304504, 0.2086919403076172, 0.4663166689872742, 1.0042074489593507]
max_get_acq = [0.20801210403442383, 0.21001195907592773, 0.39602231979370117, 0.6130349636077881, 1.1650664806365967, 1.80910325050354]
min_add_ana = [2.3351337909698486, 0.46802687644958496, 0.358020544052124, 0.356020450592041, 0.37902164459228516, 0.358020544052124]
avg_add_ana = [2.4125579977035523, 2.3468842339515685, 2.169964096546173, 2.0595978236198422, 1.9024087858200074, 1.8904581189155578]
max_add_ana = [3.235184907913208, 2.519144058227539, 2.4621407985687256, 2.5631468296051025, 2.418138265609741, 2.4431397914886475]

# %% [markdown]
# #### Get acquisition times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_get_acq,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_get_acq,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_get_acq,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when retrieving acquisition data w/ different number of analysts',
    xaxis=dict(title=dict(text="Number of analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="6b81a764-d10b-4369-ba2d-b03b917809bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6b81a764-d10b-4369-ba2d-b03b917809bf")) {
#                     Plotly.newPlot(
#                         '6b81a764-d10b-4369-ba2d-b03b917809bf',
#                         [{"name": "Minimum", "type": "bar", "uid": "b8ac381b-55ed-485d-8c12-1f00614e1e27", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.12400674819946289, 0.12300705909729004, 0.12300682067871094, 0.1240072250366211, 0.12200713157653809, 0.13300752639770508]}, {"name": "Average", "type": "bar", "uid": "76917e35-ffc2-4613-b6ec-bf8f12d9fb41", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.14027803659439086, 0.14551831007003785, 0.1644293904304504, 0.2086919403076172, 0.4663166689872742, 1.0042074489593507]}, {"name": "Maximum", "type": "bar", "uid": "a04c2ebf-babb-44c8-ae67-0918c936b8a6", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.20801210403442383, 0.21001195907592773, 0.39602231979370117, 0.6130349636077881, 1.1650664806365967, 1.80910325050354]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when retrieving acquisition data w/ different number of analysts"}, "xaxis": {"title": {"text": "Number of analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6b81a764-d10b-4369-ba2d-b03b917809bf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Add analysis times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_add_ana,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_add_ana,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_add_ana,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when executing tx AddAnalysis w/ different number of analysts',
    xaxis=dict(title=dict(text="Analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="f47abd97-3df0-4576-9e8a-e23e6500f9a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f47abd97-3df0-4576-9e8a-e23e6500f9a6")) {
#                     Plotly.newPlot(
#                         'f47abd97-3df0-4576-9e8a-e23e6500f9a6',
#                         [{"name": "Minimum", "type": "bar", "uid": "9bcd722f-7ec8-4acf-8e25-df37d4d63baa", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.3351337909698486, 0.46802687644958496, 0.358020544052124, 0.356020450592041, 0.37902164459228516, 0.358020544052124]}, {"name": "Average", "type": "bar", "uid": "9055943a-04d8-42ce-98f1-224d847edff4", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.4125579977035523, 2.3468842339515685, 2.169964096546173, 2.0595978236198422, 1.9024087858200074, 1.8904581189155578]}, {"name": "Maximum", "type": "bar", "uid": "64da98a4-7332-49a3-9efc-9fed3a23d9f2", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [3.235184907913208, 2.519144058227539, 2.4621407985687256, 2.5631468296051025, 2.418138265609741, 2.4431397914886475]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when executing tx AddAnalysis w/ different number of analysts"}, "xaxis": {"title": {"text": "Analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f47abd97-3df0-4576-9e8a-e23e6500f9a6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
