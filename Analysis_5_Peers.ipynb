# %% [markdown]
# # Real case - Analyst times (5 Peers)

# %% [markdown]
# ### Imports

# %%
import threading
import requests
import json
import random
import plotly
import plotly.graph_objs as go
from analyst import *

# %% [markdown]
# ### Global variables

# %%
API_ENDPOINT = "http://35.205.21.76:3000/api/"
NS = "ertis.uma.nuclear"

# %% [markdown]
# ### Function

# %%
def addAnalysisTest(num_analysts, num_acqs):
    analyst_threads = []
    analysis_per_worker = int(num_acqs/num_analysts)
    
    # Check for next analysis id
    resource_url = f"{API_ENDPOINT}{NS}.Analysis"
    r = requests.get(resource_url)
    next_id = len(r.json()) + 1
    
    # Create threads
    for i in range(num_analysts):
        thread = Analyst(i, f"Analyst-{i}", analysis_per_worker, next_id+analysis_per_worker*i, API_ENDPOINT, NS)
        analyst_threads.append(thread)
        
    # Start threads
    for i in range(num_analysts):
        analyst_threads[i].start()
        
    # Join threads
    for i in range(num_analysts):
        analyst_threads[i].join()
        
    # Print results
    min_get = analyst_threads[0].min_get
    avg_get = analyst_threads[0].avg_get
    max_get = analyst_threads[0].max_get
    min_add = analyst_threads[0].min_add
    avg_add = analyst_threads[0].avg_add
    max_add = analyst_threads[0].max_add
    analyst_threads[0].printResults()
    for i in range(1, num_analysts):
        if analyst_threads[i].min_get < min_get:
            min_get = analyst_threads[i].min_get

        avg_get = avg_get + analyst_threads[i].avg_get

        if analyst_threads[i].max_get > max_get:
            max_get = analyst_threads[i].max_get
            
        if analyst_threads[i].min_add < min_add:
            min_add = analyst_threads[i].min_add
            
        avg_add = avg_add + analyst_threads[i].avg_add
        
        if analyst_threads[i].max_get > max_get:
            max_add = analyst_threads[i].max_add

        analyst_threads[i].printResults()

    print(f"MIN GET ACQ --> {min_get}")
    print(f"AVG GET ACQ --> {avg_get/num_analysts}")
    print(f"MAX GET ACQ --> {max_get}")
    print(f"MIN ADD ANA --> {min_add}")
    print(f"AVG ADD ANA --> {avg_add/num_analysts}")
    print(f"MAX ADD ANA --> {max_add}")

    print("Add Analysis Test Finalized")

# %% [markdown]
# ### Execution of the test (100 analysis to do) with one single analyst

# %%
addAnalysisTest(1, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-0 has finished
# Analyst-0 - Fastest acquisition gotten in 0.12300682067871094 seconds
# Analyst-0 - Slowest acquisition gotten in 0.39402246475219727 seconds
# Analyst-0 - Average time getting acquisitions: 0.1397079920768738 seconds
# Analyst-0 - Fastest analysis added in 2.2181267738342285 seconds
# Analyst-0 - Slowest analysis added in 2.3491342067718506 seconds
# Analyst-0 - Average time adding analysis: 2.252398822307587 seconds
# MIN GET ACQ --> 0.12300682067871094
# AVG GET ACQ --> 0.1397079920768738
# MAX GET ACQ --> 0.39402246475219727
# MIN ADD ANA --> 2.2181267738342285
# AVG ADD ANA --> 2.252398822307587
# MAX ADD ANA --> 2.3491342067718506
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with two (2) analysts

# %%
addAnalysisTest(2, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
#
# Analyst Analyst-1 has finished
# Analyst Analyst-0 has finished
# Analyst-0 - Fastest acquisition gotten in 0.12300705909729004 seconds
# Analyst-0 - Slowest acquisition gotten in 0.20801162719726562 seconds
# Analyst-0 - Average time getting acquisitions: 0.14372823715209962 seconds
# Analyst-0 - Fastest analysis added in 0.49202823638916016 seconds
# Analyst-0 - Slowest analysis added in 2.633150815963745 seconds
# Analyst-0 - Average time adding analysis: 2.164023771286011 seconds
# Analyst-1 - Fastest acquisition gotten in 0.12300705909729004 seconds
# Analyst-1 - Slowest acquisition gotten in 0.2170124053955078 seconds
# Analyst-1 - Average time getting acquisitions: 0.14158812999725343 seconds
# Analyst-1 - Fastest analysis added in 0.3110177516937256 seconds
# Analyst-1 - Slowest analysis added in 2.419138193130493 seconds
# Analyst-1 - Average time adding analysis: 2.1512830305099486 seconds
# MIN GET ACQ --> 0.12300705909729004
# AVG GET ACQ --> 0.14265818357467652
# MAX GET ACQ --> 0.2170124053955078
# MIN ADD ANA --> 0.3110177516937256
# AVG ADD ANA --> 2.1576534008979795
# MAX ADD ANA --> 2.633150815963745
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with five (5) analysts

# %%
addAnalysisTest(5, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
#
# Analyst Analyst-2 has started
# Analyst Analyst-3 has started
# Analyst Analyst-4 has started
# Analyst Analyst-2 has finished
# Analyst Analyst-3 has finished
# Analyst Analyst-4 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-0 has finished
# Analyst-0 - Fastest acquisition gotten in 0.12300705909729004 seconds
# Analyst-0 - Slowest acquisition gotten in 0.38602209091186523 seconds
# Analyst-0 - Average time getting acquisitions: 0.15575895309448243 seconds
# Analyst-0 - Fastest analysis added in 0.6170351505279541 seconds
# Analyst-0 - Slowest analysis added in 2.306131601333618 seconds
# Analyst-0 - Average time adding analysis: 2.068218231201172 seconds
# Analyst-1 - Fastest acquisition gotten in 0.1260073184967041 seconds
# Analyst-1 - Slowest acquisition gotten in 0.3690211772918701 seconds
# Analyst-1 - Average time getting acquisitions: 0.16215933561325074 seconds
# Analyst-1 - Fastest analysis added in 2.2191269397735596 seconds
# Analyst-1 - Slowest analysis added in 2.3231327533721924 seconds
# Analyst-1 - Average time adding analysis: 2.2513787269592287 seconds
# Analyst-2 - Fastest acquisition gotten in 0.12700724601745605 seconds
# Analyst-2 - Slowest acquisition gotten in 0.36402058601379395 seconds
# Analyst-2 - Average time getting acquisitions: 0.1595591425895691 seconds
# Analyst-2 - Fastest analysis added in 0.8050460815429688 seconds
# Analyst-2 - Slowest analysis added in 2.297131299972534 seconds
# Analyst-2 - Average time adding analysis: 1.9650124073028565 seconds
# Analyst-3 - Fastest acquisition gotten in 0.1280074119567871 seconds
# Analyst-3 - Slowest acquisition gotten in 0.3710212707519531 seconds
# Analyst-3 - Average time getting acquisitions: 0.1624092936515808 seconds
# Analyst-3 - Fastest analysis added in 0.8380477428436279 seconds
# Analyst-3 - Slowest analysis added in 2.372135639190674 seconds
# Analyst-3 - Average time adding analysis: 2.1432225465774537 seconds
# Analyst-4 - Fastest acquisition gotten in 0.12400674819946289 seconds
# Analyst-4 - Slowest acquisition gotten in 0.361020565032959 seconds
# Analyst-4 - Average time getting acquisitions: 0.16295926570892333 seconds
# Analyst-4 - Fastest analysis added in 1.2650723457336426 seconds
# Analyst-4 - Slowest analysis added in 2.896165609359741 seconds
# Analyst-4 - Average time adding analysis: 2.238278067111969 seconds
# MIN GET ACQ --> 0.12300705909729004
# AVG GET ACQ --> 0.16056919813156129
# MAX GET ACQ --> 0.38602209091186523
# MIN ADD ANA --> 0.6170351505279541
# AVG ADD ANA --> 2.133221995830536
# MAX ADD ANA --> 2.306131601333618
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with ten (10) analysts

# %%
addAnalysisTest(10, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has started
# Analyst Analyst-2 has started
# Analyst Analyst-3 has started
# Analyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has started
# Analyst Analyst-7 has startedAnalyst Analyst-8 has started
#
# Analyst Analyst-9 has started
# Analyst Analyst-5 has finished
# Analyst Analyst-9 has finished
# Analyst Analyst-2 has finished
# Analyst Analyst-0 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-4 has finished
# Analyst Analyst-8 has finished
# Analyst Analyst-6 has finishedAnalyst Analyst-3 has finished
#
# Analyst Analyst-7 has finished
# Analyst-0 - Fastest acquisition gotten in 0.13000726699829102 seconds
# Analyst-0 - Slowest acquisition gotten in 0.39402246475219727 seconds
# Analyst-0 - Average time getting acquisitions: 0.20311157703399657 seconds
# Analyst-0 - Fastest analysis added in 0.5090291500091553 seconds
# Analyst-0 - Slowest analysis added in 2.3611347675323486 seconds
# Analyst-0 - Average time adding analysis: 1.8563061952590942 seconds
# Analyst-1 - Fastest acquisition gotten in 0.12500715255737305 seconds
# Analyst-1 - Slowest acquisition gotten in 0.5660324096679688 seconds
# Analyst-1 - Average time getting acquisitions: 0.22161266803741456 seconds
# Analyst-1 - Fastest analysis added in 0.43102455139160156 seconds
# Analyst-1 - Slowest analysis added in 2.2431282997131348 seconds
# Analyst-1 - Average time adding analysis: 1.7375993728637695 seconds
# Analyst-2 - Fastest acquisition gotten in 0.12300705909729004 seconds
# Analyst-2 - Slowest acquisition gotten in 0.5540316104888916 seconds
# Analyst-2 - Average time getting acquisitions: 0.22121262550354004 seconds
# Analyst-2 - Fastest analysis added in 1.3470771312713623 seconds
# Analyst-2 - Slowest analysis added in 2.3531346321105957 seconds
# Analyst-2 - Average time adding analysis: 2.1888252019882204 seconds
# Analyst-3 - Fastest acquisition gotten in 0.13400793075561523 seconds
# Analyst-3 - Slowest acquisition gotten in 0.6060347557067871 seconds
# Analyst-3 - Average time getting acquisitions: 0.21091220378875733 seconds
# Analyst-3 - Fastest analysis added in 0.9540543556213379 seconds
# Analyst-3 - Slowest analysis added in 2.270129919052124 seconds
# Analyst-3 - Average time adding analysis: 2.03141610622406 seconds
# Analyst-4 - Fastest acquisition gotten in 0.13600778579711914 seconds
# Analyst-4 - Slowest acquisition gotten in 0.6190354824066162 seconds
# Analyst-4 - Average time getting acquisitions: 0.21701245307922362 seconds
# Analyst-4 - Fastest analysis added in 1.1420655250549316 seconds
# Analyst-4 - Slowest analysis added in 2.280130386352539 seconds
# Analyst-4 - Average time adding analysis: 2.0402166843414307 seconds
# Analyst-5 - Fastest acquisition gotten in 0.12500715255737305 seconds
# Analyst-5 - Slowest acquisition gotten in 0.6440370082855225 seconds
# Analyst-5 - Average time getting acquisitions: 0.22441282272338867 seconds
# Analyst-5 - Fastest analysis added in 1.074061393737793 seconds
# Analyst-5 - Slowest analysis added in 2.2951314449310303 seconds
# Analyst-5 - Average time adding analysis: 1.866906762123108 seconds
# Analyst-6 - Fastest acquisition gotten in 0.128007173538208 seconds
# Analyst-6 - Slowest acquisition gotten in 0.6210355758666992 seconds
# Analyst-6 - Average time getting acquisitions: 0.20701179504394532 seconds
# Analyst-6 - Fastest analysis added in 1.9731128215789795 seconds
# Analyst-6 - Slowest analysis added in 2.3111319541931152 seconds
# Analyst-6 - Average time adding analysis: 2.233827805519104 seconds
# Analyst-7 - Fastest acquisition gotten in 0.1260068416595459 seconds
# Analyst-7 - Slowest acquisition gotten in 0.5850334167480469 seconds
# Analyst-7 - Average time getting acquisitions: 0.20191147327423095 seconds
# Analyst-7 - Fastest analysis added in 0.29401683807373047 seconds
# Analyst-7 - Slowest analysis added in 2.2861311435699463 seconds
# Analyst-7 - Average time adding analysis: 1.8620064973831176 seconds
# Analyst-8 - Fastest acquisition gotten in 0.12700724601745605 seconds
# Analyst-8 - Slowest acquisition gotten in 0.5710327625274658 seconds
# Analyst-8 - Average time getting acquisitions: 0.20221152305603027 seconds
# Analyst-8 - Fastest analysis added in 0.8300473690032959 seconds
# Analyst-8 - Slowest analysis added in 2.3131322860717773 seconds
# Analyst-8 - Average time adding analysis: 2.058817720413208 seconds
# Analyst-9 - Fastest acquisition gotten in 0.1280074119567871 seconds
# Analyst-9 - Slowest acquisition gotten in 0.5850334167480469 seconds
# Analyst-9 - Average time getting acquisitions: 0.20871195793151856 seconds
# Analyst-9 - Fastest analysis added in 0.45302605628967285 seconds
# Analyst-9 - Slowest analysis added in 2.3221325874328613 seconds
# Analyst-9 - Average time adding analysis: 2.0789188623428343 seconds
# MIN GET ACQ --> 0.12300705909729004
# AVG GET ACQ --> 0.21181210994720456
# MAX GET ACQ --> 0.6440370082855225
# MIN ADD ANA --> 0.29401683807373047
# AVG ADD ANA --> 1.9954841208457945
# MAX ADD ANA --> 2.3611347675323486
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with twenty five (25) analysts

# %%
addAnalysisTest(25, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has started
# Analyst Analyst-2 has started
# Analyst Analyst-3 has startedAnalyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has started
#
# Analyst Analyst-7 has started
# Analyst Analyst-8 has startedAnalyst Analyst-9 has started
# Analyst Analyst-10 has started
#
# Analyst Analyst-11 has started
# Analyst Analyst-12 has started
# Analyst Analyst-13 has started
# Analyst Analyst-14 has started
# Analyst Analyst-15 has started
# Analyst Analyst-16 has started
# Analyst Analyst-17 has started
# Analyst Analyst-18 has started
# Analyst Analyst-19 has started
# Analyst Analyst-20 has started
# Analyst Analyst-21 has started
# Analyst Analyst-22 has started
# Analyst Analyst-23 has started
# Analyst Analyst-24 has started
# Analyst Analyst-17 has finished
# Analyst Analyst-19 has finishedAnalyst Analyst-24 has finished
#
# Analyst Analyst-13 has finishedAnalyst Analyst-1 has finished
#
# Analyst Analyst-20 has finished
# Analyst Analyst-0 has finishedAnalyst Analyst-10 has finished
#
# Analyst Analyst-9 has finished
# Analyst Analyst-22 has finishedAnalyst Analyst-3 has finished
#
# Analyst Analyst-16 has finishedAnalyst Analyst-21 has finished
# Analyst Analyst-8 has finished
#
# Analyst Analyst-14 has finished
# Analyst Analyst-11 has finishedAnalyst Analyst-12 has finished
#
# Analyst Analyst-4 has finished
# Analyst Analyst-15 has finishedAnalyst Analyst-7 has finished
#
# Analyst Analyst-6 has finished
# Analyst Analyst-2 has finished
# Analyst Analyst-5 has finished
# Analyst Analyst-23 has finishedAnalyst Analyst-18 has finished
#
# Analyst-0 - Fastest acquisition gotten in 0.18101024627685547 seconds
# Analyst-0 - Slowest acquisition gotten in 1.2660727500915527 seconds
# Analyst-0 - Average time getting acquisitions: 0.4747771620750427 seconds
# Analyst-0 - Fastest analysis added in 0.4760274887084961 seconds
# Analyst-0 - Slowest analysis added in 2.303131580352783 seconds
# Analyst-0 - Average time adding analysis: 1.5915910601615906 seconds
# Analyst-1 - Fastest acquisition gotten in 0.1870105266571045 seconds
# Analyst-1 - Slowest acquisition gotten in 1.2830734252929688 seconds
# Analyst-1 - Average time getting acquisitions: 0.48627781867980957 seconds
# Analyst-1 - Fastest analysis added in 0.356020450592041 seconds
# Analyst-1 - Slowest analysis added in 2.362135171890259 seconds
# Analyst-1 - Average time adding analysis: 1.6253429651260376 seconds
# Analyst-2 - Fastest acquisition gotten in 0.16700959205627441 seconds
# Analyst-2 - Slowest acquisition gotten in 1.2630722522735596 seconds
# Analyst-2 - Average time getting acquisitions: 0.4450255036354065 seconds
# Analyst-2 - Fastest analysis added in 0.42002415657043457 seconds
# Analyst-2 - Slowest analysis added in 2.249128580093384 seconds
# Analyst-2 - Average time adding analysis: 1.5618394017219543 seconds
# Analyst-3 - Fastest acquisition gotten in 0.241013765335083 seconds
# Analyst-3 - Slowest acquisition gotten in 1.2450711727142334 seconds
# Analyst-3 - Average time getting acquisitions: 0.5150293111801147 seconds
# Analyst-3 - Fastest analysis added in 0.30101728439331055 seconds
# Analyst-3 - Slowest analysis added in 2.2001256942749023 seconds
# Analyst-3 - Average time adding analysis: 1.2435711026191711 seconds
# Analyst-4 - Fastest acquisition gotten in 0.15900921821594238 seconds
# Analyst-4 - Slowest acquisition gotten in 1.3430767059326172 seconds
# Analyst-4 - Average time getting acquisitions: 0.5125292539596558 seconds
# Analyst-4 - Fastest analysis added in 0.30501770973205566 seconds
# Analyst-4 - Slowest analysis added in 2.2971315383911133 seconds
# Analyst-4 - Average time adding analysis: 1.5298375487327576 seconds
# Analyst-5 - Fastest acquisition gotten in 0.13400745391845703 seconds
# Analyst-5 - Slowest acquisition gotten in 1.305074691772461 seconds
# Analyst-5 - Average time getting acquisitions: 0.43877506256103516 seconds
# Analyst-5 - Fastest analysis added in 2.2331278324127197 seconds
# Analyst-5 - Slowest analysis added in 2.3321332931518555 seconds
# Analyst-5 - Average time adding analysis: 2.275630235671997 seconds
# Analyst-6 - Fastest acquisition gotten in 0.241013765335083 seconds
# Analyst-6 - Slowest acquisition gotten in 1.2630722522735596 seconds
# Analyst-6 - Average time getting acquisitions: 0.5220299363136292 seconds
# Analyst-6 - Fastest analysis added in 0.8030462265014648 seconds
# Analyst-6 - Slowest analysis added in 2.3111321926116943 seconds
# Analyst-6 - Average time adding analysis: 1.7205985188484192 seconds
# Analyst-7 - Fastest acquisition gotten in 0.18501067161560059 seconds
# Analyst-7 - Slowest acquisition gotten in 1.3770787715911865 seconds
# Analyst-7 - Average time getting acquisitions: 0.5207799077033997 seconds
# Analyst-7 - Fastest analysis added in 0.28801655769348145 seconds
# Analyst-7 - Slowest analysis added in 2.3131322860717773 seconds
# Analyst-7 - Average time adding analysis: 1.2270702123641968 seconds
# Analyst-8 - Fastest acquisition gotten in 0.13200759887695312 seconds
# Analyst-8 - Slowest acquisition gotten in 1.3700785636901855 seconds
# Analyst-8 - Average time getting acquisitions: 0.48527783155441284 seconds
# Analyst-8 - Fastest analysis added in 1.208069086074829 seconds
# Analyst-8 - Slowest analysis added in 2.414138078689575 seconds
# Analyst-8 - Average time adding analysis: 2.0206156373023987 seconds
# Analyst-9 - Fastest acquisition gotten in 0.18501043319702148 seconds
# Analyst-9 - Slowest acquisition gotten in 1.3940796852111816 seconds
# Analyst-9 - Average time getting acquisitions: 0.5185295939445496 seconds
# Analyst-9 - Fastest analysis added in 1.433081865310669 seconds
# Analyst-9 - Slowest analysis added in 2.2981314659118652 seconds
# Analyst-9 - Average time adding analysis: 2.0611178874969482 seconds
# Analyst-10 - Fastest acquisition gotten in 0.2000112533569336 seconds
# Analyst-10 - Slowest acquisition gotten in 1.330075740814209 seconds
# Analyst-10 - Average time getting acquisitions: 0.5060287117958069 seconds
# Analyst-10 - Fastest analysis added in 1.1480655670166016 seconds
# Analyst-10 - Slowest analysis added in 2.2211270332336426 seconds
# Analyst-10 - Average time adding analysis: 1.5453384518623352 seconds
# Analyst-11 - Fastest acquisition gotten in 0.13000750541687012 seconds
# Analyst-11 - Slowest acquisition gotten in 1.3570773601531982 seconds
# Analyst-11 - Average time getting acquisitions: 0.4642765522003174 seconds
# Analyst-11 - Fastest analysis added in 1.2310705184936523 seconds
# Analyst-11 - Slowest analysis added in 2.277130365371704 seconds
# Analyst-11 - Average time adding analysis: 1.8183540105819702 seconds
# Analyst-12 - Fastest acquisition gotten in 0.1410079002380371 seconds
# Analyst-12 - Slowest acquisition gotten in 1.2780730724334717 seconds
# Analyst-12 - Average time getting acquisitions: 0.4687768220901489 seconds
# Analyst-12 - Fastest analysis added in 1.2110693454742432 seconds
# Analyst-12 - Slowest analysis added in 2.251128673553467 seconds
# Analyst-12 - Average time adding analysis: 1.8103536367416382 seconds
# Analyst-13 - Fastest acquisition gotten in 0.2110121250152588 seconds
# Analyst-13 - Slowest acquisition gotten in 1.2920737266540527 seconds
# Analyst-13 - Average time getting acquisitions: 0.5245299935340881 seconds
# Analyst-13 - Fastest analysis added in 1.1560659408569336 seconds
# Analyst-13 - Slowest analysis added in 2.518144369125366 seconds
# Analyst-13 - Average time adding analysis: 2.0698684453964233 seconds
# Analyst-14 - Fastest acquisition gotten in 0.19501113891601562 seconds
# Analyst-14 - Slowest acquisition gotten in 1.301074504852295 seconds
# Analyst-14 - Average time getting acquisitions: 0.5282802581787109 seconds
# Analyst-14 - Fastest analysis added in 1.2490713596343994 seconds
# Analyst-14 - Slowest analysis added in 2.4761414527893066 seconds
# Analyst-14 - Average time adding analysis: 1.9963642358779907 seconds
# Analyst-15 - Fastest acquisition gotten in 0.1890108585357666 seconds
# Analyst-15 - Slowest acquisition gotten in 1.2420711517333984 seconds
# Analyst-15 - Average time getting acquisitions: 0.4837777018547058 seconds
# Analyst-15 - Fastest analysis added in 1.8931083679199219 seconds
# Analyst-15 - Slowest analysis added in 2.5491459369659424 seconds
# Analyst-15 - Average time adding analysis: 2.2501288056373596 seconds
# Analyst-16 - Fastest acquisition gotten in 0.12700724601745605 seconds
# Analyst-16 - Slowest acquisition gotten in 1.1690669059753418 seconds
# Analyst-16 - Average time getting acquisitions: 0.44952577352523804 seconds
# Analyst-16 - Fastest analysis added in 0.3450195789337158 seconds
# Analyst-16 - Slowest analysis added in 2.292131185531616 seconds
# Analyst-16 - Average time adding analysis: 1.793602466583252 seconds
# Analyst-17 - Fastest acquisition gotten in 0.20801210403442383 seconds
# Analyst-17 - Slowest acquisition gotten in 1.2520713806152344 seconds
# Analyst-17 - Average time getting acquisitions: 0.49977850914001465 seconds
# Analyst-17 - Fastest analysis added in 1.2780730724334717 seconds
# Analyst-17 - Slowest analysis added in 2.290131092071533 seconds
# Analyst-17 - Average time adding analysis: 2.022115707397461 seconds
# Analyst-18 - Fastest acquisition gotten in 0.14000821113586426 seconds
# Analyst-18 - Slowest acquisition gotten in 1.322075605392456 seconds
# Analyst-18 - Average time getting acquisitions: 0.4630265235900879 seconds
# Analyst-18 - Fastest analysis added in 1.2260701656341553 seconds
# Analyst-18 - Slowest analysis added in 2.3171324729919434 seconds
# Analyst-18 - Average time adding analysis: 1.7633508443832397 seconds
# Analyst-19 - Fastest acquisition gotten in 0.18601083755493164 seconds
# Analyst-19 - Slowest acquisition gotten in 1.3530774116516113 seconds
# Analyst-19 - Average time getting acquisitions: 0.48752784729003906 seconds
# Analyst-19 - Fastest analysis added in 1.5040860176086426 seconds
# Analyst-19 - Slowest analysis added in 2.275130271911621 seconds
# Analyst-19 - Average time adding analysis: 2.0343663692474365 seconds
# Analyst-20 - Fastest acquisition gotten in 0.17500972747802734 seconds
# Analyst-20 - Slowest acquisition gotten in 1.320075511932373 seconds
# Analyst-20 - Average time getting acquisitions: 0.46977680921554565 seconds
# Analyst-20 - Fastest analysis added in 1.3920795917510986 seconds
# Analyst-20 - Slowest analysis added in 2.4731411933898926 seconds
# Analyst-20 - Average time adding analysis: 2.062617838382721 seconds
# Analyst-21 - Fastest acquisition gotten in 0.2560145854949951 seconds
# Analyst-21 - Slowest acquisition gotten in 1.3070745468139648 seconds
# Analyst-21 - Average time getting acquisitions: 0.5270300507545471 seconds
# Analyst-21 - Fastest analysis added in 1.4830846786499023 seconds
# Analyst-21 - Slowest analysis added in 2.275130271911621 seconds
# Analyst-21 - Average time adding analysis: 1.9591121077537537 seconds
# Analyst-22 - Fastest acquisition gotten in 0.13400745391845703 seconds
# Analyst-22 - Slowest acquisition gotten in 1.329075813293457 seconds
# Analyst-22 - Average time getting acquisitions: 0.482277512550354 seconds
# Analyst-22 - Fastest analysis added in 2.2291274070739746 seconds
# Analyst-22 - Slowest analysis added in 2.273129940032959 seconds
# Analyst-22 - Average time adding analysis: 2.2473784685134888 seconds
# Analyst-23 - Fastest acquisition gotten in 0.1780099868774414 seconds
# Analyst-23 - Slowest acquisition gotten in 1.3360764980316162 seconds
# Analyst-23 - Average time getting acquisitions: 0.4897780418395996 seconds
# Analyst-23 - Fastest analysis added in 0.8240470886230469 seconds
# Analyst-23 - Slowest analysis added in 2.4691410064697266 seconds
# Analyst-23 - Average time adding analysis: 1.9783632159233093 seconds
# Analyst-24 - Fastest acquisition gotten in 0.1630091667175293 seconds
# Analyst-24 - Slowest acquisition gotten in 1.309074878692627 seconds
# Analyst-24 - Average time getting acquisitions: 0.5022786259651184 seconds
# Analyst-24 - Fastest analysis added in 0.3890223503112793 seconds
# Analyst-24 - Slowest analysis added in 2.3491344451904297 seconds
# Analyst-24 - Average time adding analysis: 1.7633509635925293 seconds
# MIN GET ACQ --> 0.12700724601745605
# AVG GET ACQ --> 0.4906280446052551
# MAX GET ACQ --> 1.3940796852111816
# MIN ADD ANA --> 0.28801655769348145
# AVG ADD ANA --> 1.8388752055168152
# MAX ADD ANA --> 2.303131580352783
# Add Analysis Test Finalized

# %% [markdown]
# ### Execution of the test (100 analysis to do) with fifty (50) analysts

# %%
addAnalysisTest(50, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
# Analyst Analyst-2 has started
# Analyst Analyst-3 has started
#
# Analyst Analyst-4 has startedAnalyst Analyst-5 has started
#
# Analyst Analyst-6 has startedAnalyst Analyst-7 has started
#
# Analyst Analyst-8 has started
# Analyst Analyst-9 has started
# Analyst Analyst-10 has started
# Analyst Analyst-11 has started
# Analyst Analyst-12 has started
# Analyst Analyst-13 has started
# Analyst Analyst-14 has started
# Analyst Analyst-15 has started
# Analyst Analyst-16 has started
# Analyst Analyst-17 has startedAnalyst Analyst-18 has started
#
# Analyst Analyst-19 has started
# Analyst Analyst-20 has started
# Analyst Analyst-21 has started
# Analyst Analyst-22 has started
# Analyst Analyst-23 has started
# Analyst Analyst-24 has started
# Analyst Analyst-25 has startedAnalyst Analyst-26 has started
#
# Analyst Analyst-27 has startedAnalyst Analyst-28 has started
#
# Analyst Analyst-29 has started
# Analyst Analyst-30 has started
# Analyst Analyst-31 has started
# Analyst Analyst-32 has started
# Analyst Analyst-33 has started
# Analyst Analyst-34 has started
# Analyst Analyst-35 has started
# Analyst Analyst-36 has started
# Analyst Analyst-37 has started
# Analyst Analyst-38 has started
# Analyst Analyst-39 has started
# Analyst Analyst-40 has started
# Analyst Analyst-41 has started
# Analyst Analyst-42 has started
# Analyst Analyst-43 has startedAnalyst Analyst-44 has started
#
# Analyst Analyst-45 has started
# Analyst Analyst-46 has startedAnalyst Analyst-47 has started
#
# Analyst Analyst-48 has started
# Analyst Analyst-49 has started
# Analyst Analyst-2 has finishedAnalyst Analyst-3 has finished
#
# Analyst Analyst-32 has finishedAnalyst Analyst-11 has finished
#
# Analyst Analyst-41 has finishedAnalyst Analyst-47 has finished
#
# Analyst Analyst-20 has finishedAnalyst Analyst-22 has finishedAnalyst Analyst-36 has finished
#
#
# Analyst Analyst-35 has finishedAnalyst Analyst-12 has finished
#
# Analyst Analyst-5 has finished
# Analyst Analyst-39 has finishedAnalyst Analyst-0 has finished
#
# Analyst Analyst-34 has finishedAnalyst Analyst-10 has finished
# Analyst Analyst-25 has finished
#
# Analyst Analyst-44 has finished
# Analyst Analyst-8 has finished
# Analyst Analyst-45 has finished
# Analyst Analyst-17 has finishedAnalyst Analyst-37 has finished
#
# Analyst Analyst-9 has finished
# Analyst Analyst-40 has finished
# Analyst Analyst-6 has finished
# Analyst Analyst-13 has finished
# Analyst Analyst-33 has finished
# Analyst Analyst-19 has finished
# Analyst Analyst-4 has finishedAnalyst Analyst-29 has finished
#
# Analyst Analyst-49 has finishedAnalyst Analyst-38 has finished
# Analyst Analyst-46 has finished
#
# Analyst Analyst-16 has finishedAnalyst Analyst-23 has finishedAnalyst Analyst-18 has finished
# Analyst Analyst-26 has finished
#
# Analyst Analyst-30 has finished
#
# Analyst Analyst-7 has finished
# Analyst Analyst-48 has finishedAnalyst Analyst-43 has finished
# Analyst Analyst-31 has finished
#
# Analyst Analyst-27 has finishedAnalyst Analyst-21 has finished
#
# Analyst Analyst-28 has finished
# Analyst Analyst-14 has finishedAnalyst Analyst-42 has finished
#
# Analyst Analyst-1 has finished
# Analyst Analyst-15 has finishedAnalyst Analyst-24 has finished
#
# Analyst-0 - Fastest acquisition gotten in 0.3020172119140625 seconds
# Analyst-0 - Slowest acquisition gotten in 2.0701184272766113 seconds
# Analyst-0 - Average time getting acquisitions: 1.186067819595337 seconds
# Analyst-0 - Fastest analysis added in 0.948054313659668 seconds
# Analyst-0 - Slowest analysis added in 1.1740672588348389 seconds
# Analyst-0 - Average time adding analysis: 1.0610607862472534 seconds
# Analyst-1 - Fastest acquisition gotten in 0.3850221633911133 seconds
# Analyst-1 - Slowest acquisition gotten in 2.242128372192383 seconds
# Analyst-1 - Average time getting acquisitions: 1.313575267791748 seconds
# Analyst-1 - Fastest analysis added in 2.2331278324127197 seconds
# Analyst-1 - Slowest analysis added in 2.265129566192627 seconds
# Analyst-1 - Average time adding analysis: 2.2491286993026733 seconds
# Analyst-2 - Fastest acquisition gotten in 0.39002227783203125 seconds
# Analyst-2 - Slowest acquisition gotten in 2.2171266078948975 seconds
# Analyst-2 - Average time getting acquisitions: 1.3035744428634644 seconds
# Analyst-2 - Fastest analysis added in 2.250128746032715 seconds
# Analyst-2 - Slowest analysis added in 2.494142532348633 seconds
# Analyst-2 - Average time adding analysis: 2.372135639190674 seconds
# Analyst-3 - Fastest acquisition gotten in 0.4580259323120117 seconds
# Analyst-3 - Slowest acquisition gotten in 2.161123514175415 seconds
# Analyst-3 - Average time getting acquisitions: 1.3095747232437134 seconds
# Analyst-3 - Fastest analysis added in 0.7120406627655029 seconds
# Analyst-3 - Slowest analysis added in 1.0060575008392334 seconds
# Analyst-3 - Average time adding analysis: 0.8590490818023682 seconds
# Analyst-4 - Fastest acquisition gotten in 0.3220183849334717 seconds
# Analyst-4 - Slowest acquisition gotten in 2.247128486633301 seconds
# Analyst-4 - Average time getting acquisitions: 1.2845734357833862 seconds
# Analyst-4 - Fastest analysis added in 1.1290645599365234 seconds
# Analyst-4 - Slowest analysis added in 1.4970855712890625 seconds
# Analyst-4 - Average time adding analysis: 1.313075065612793 seconds
# Analyst-5 - Fastest acquisition gotten in 0.41802382469177246 seconds
# Analyst-5 - Slowest acquisition gotten in 2.14512300491333 seconds
# Analyst-5 - Average time getting acquisitions: 1.2815734148025513 seconds
# Analyst-5 - Fastest analysis added in 1.3760788440704346 seconds
# Analyst-5 - Slowest analysis added in 1.549088716506958 seconds
# Analyst-5 - Average time adding analysis: 1.4625837802886963 seconds
# Analyst-6 - Fastest acquisition gotten in 0.47302699089050293 seconds
# Analyst-6 - Slowest acquisition gotten in 2.1951253414154053 seconds
# Analyst-6 - Average time getting acquisitions: 1.334076166152954 seconds
# Analyst-6 - Fastest analysis added in 0.6400365829467773 seconds
# Analyst-6 - Slowest analysis added in 1.3770787715911865 seconds
# Analyst-6 - Average time adding analysis: 1.008557677268982 seconds
# Analyst-7 - Fastest acquisition gotten in 0.32001829147338867 seconds
# Analyst-7 - Slowest acquisition gotten in 2.291131019592285 seconds
# Analyst-7 - Average time getting acquisitions: 1.305574655532837 seconds
# Analyst-7 - Fastest analysis added in 0.6930396556854248 seconds
# Analyst-7 - Slowest analysis added in 2.280130624771118 seconds
# Analyst-7 - Average time adding analysis: 1.4865851402282715 seconds
# Analyst-8 - Fastest acquisition gotten in 0.16700959205627441 seconds
# Analyst-8 - Slowest acquisition gotten in 2.04111647605896 seconds
# Analyst-8 - Average time getting acquisitions: 1.1040630340576172 seconds
# Analyst-8 - Fastest analysis added in 0.6800389289855957 seconds
# Analyst-8 - Slowest analysis added in 1.4510829448699951 seconds
# Analyst-8 - Average time adding analysis: 1.0655609369277954 seconds
# Analyst-9 - Fastest acquisition gotten in 0.29701709747314453 seconds
# Analyst-9 - Slowest acquisition gotten in 2.1841249465942383 seconds
# Analyst-9 - Average time getting acquisitions: 1.2405710220336914 seconds
# Analyst-9 - Fastest analysis added in 0.7900452613830566 seconds
# Analyst-9 - Slowest analysis added in 1.4060804843902588 seconds
# Analyst-9 - Average time adding analysis: 1.0980628728866577 seconds
# Analyst-10 - Fastest acquisition gotten in 0.36602091789245605 seconds
# Analyst-10 - Slowest acquisition gotten in 2.150122880935669 seconds
# Analyst-10 - Average time getting acquisitions: 1.2580718994140625 seconds
# Analyst-10 - Fastest analysis added in 0.6580376625061035 seconds
# Analyst-10 - Slowest analysis added in 1.1260645389556885 seconds
# Analyst-10 - Average time adding analysis: 0.892051100730896 seconds
# Analyst-11 - Fastest acquisition gotten in 0.2020113468170166 seconds
# Analyst-11 - Slowest acquisition gotten in 2.1911253929138184 seconds
# Analyst-11 - Average time getting acquisitions: 1.1965683698654175 seconds
# Analyst-11 - Fastest analysis added in 0.43802499771118164 seconds
# Analyst-11 - Slowest analysis added in 1.6560947895050049 seconds
# Analyst-11 - Average time adding analysis: 1.0470598936080933 seconds
# Analyst-12 - Fastest acquisition gotten in 0.37702155113220215 seconds
# Analyst-12 - Slowest acquisition gotten in 2.250128984451294 seconds
# Analyst-12 - Average time getting acquisitions: 1.313575267791748 seconds
# Analyst-12 - Fastest analysis added in 1.3680782318115234 seconds
# Analyst-12 - Slowest analysis added in 1.4230811595916748 seconds
# Analyst-12 - Average time adding analysis: 1.3955796957015991 seconds
# Analyst-13 - Fastest acquisition gotten in 0.29001665115356445 seconds
# Analyst-13 - Slowest acquisition gotten in 2.139122486114502 seconds
# Analyst-13 - Average time getting acquisitions: 1.2145695686340332 seconds
# Analyst-13 - Fastest analysis added in 0.7950453758239746 seconds
# Analyst-13 - Slowest analysis added in 1.4130806922912598 seconds
# Analyst-13 - Average time adding analysis: 1.1040630340576172 seconds
# Analyst-14 - Fastest acquisition gotten in 0.3170180320739746 seconds
# Analyst-14 - Slowest acquisition gotten in 2.146122455596924 seconds
# Analyst-14 - Average time getting acquisitions: 1.2315702438354492 seconds
# Analyst-14 - Fastest analysis added in 2.277130365371704 seconds
# Analyst-14 - Slowest analysis added in 2.3561346530914307 seconds
# Analyst-14 - Average time adding analysis: 2.3166325092315674 seconds
# Analyst-15 - Fastest acquisition gotten in 0.38302183151245117 seconds
# Analyst-15 - Slowest acquisition gotten in 2.1301217079162598 seconds
# Analyst-15 - Average time getting acquisitions: 1.2565717697143555 seconds
# Analyst-15 - Fastest analysis added in 1.2580718994140625 seconds
# Analyst-15 - Slowest analysis added in 2.291131019592285 seconds
# Analyst-15 - Average time adding analysis: 1.7746014595031738 seconds
# Analyst-16 - Fastest acquisition gotten in 0.2950170040130615 seconds
# Analyst-16 - Slowest acquisition gotten in 2.136121988296509 seconds
# Analyst-16 - Average time getting acquisitions: 1.2155694961547852 seconds
# Analyst-16 - Fastest analysis added in 1.5040860176086426 seconds
# Analyst-16 - Slowest analysis added in 1.560089349746704 seconds
# Analyst-16 - Average time adding analysis: 1.5320876836776733 seconds
# Analyst-17 - Fastest acquisition gotten in 0.1240072250366211 seconds
# Analyst-17 - Slowest acquisition gotten in 2.168123960494995 seconds
# Analyst-17 - Average time getting acquisitions: 1.146065592765808 seconds
# Analyst-17 - Fastest analysis added in 2.039116621017456 seconds
# Analyst-17 - Slowest analysis added in 2.247128486633301 seconds
# Analyst-17 - Average time adding analysis: 2.1431225538253784 seconds
# Analyst-18 - Fastest acquisition gotten in 0.3390192985534668 seconds
# Analyst-18 - Slowest acquisition gotten in 2.1081206798553467 seconds
# Analyst-18 - Average time getting acquisitions: 1.2235699892044067 seconds
# Analyst-18 - Fastest analysis added in 0.5530316829681396 seconds
# Analyst-18 - Slowest analysis added in 1.4740843772888184 seconds
# Analyst-18 - Average time adding analysis: 1.013558030128479 seconds
# Analyst-19 - Fastest acquisition gotten in 0.32001829147338867 seconds
# Analyst-19 - Slowest acquisition gotten in 2.12412166595459 seconds
# Analyst-19 - Average time getting acquisitions: 1.2220699787139893 seconds
# Analyst-19 - Fastest analysis added in 1.3410766124725342 seconds
# Analyst-19 - Slowest analysis added in 2.265129327774048 seconds
# Analyst-19 - Average time adding analysis: 1.803102970123291 seconds
# Analyst-20 - Fastest acquisition gotten in 0.4220240116119385 seconds
# Analyst-20 - Slowest acquisition gotten in 2.0981199741363525 seconds
# Analyst-20 - Average time getting acquisitions: 1.2600719928741455 seconds
# Analyst-20 - Fastest analysis added in 1.438082218170166 seconds
# Analyst-20 - Slowest analysis added in 2.266129732131958 seconds
# Analyst-20 - Average time adding analysis: 1.852105975151062 seconds
# Analyst-21 - Fastest acquisition gotten in 0.17200970649719238 seconds
# Analyst-21 - Slowest acquisition gotten in 2.108120918273926 seconds
# Analyst-21 - Average time getting acquisitions: 1.140065312385559 seconds
# Analyst-21 - Fastest analysis added in 1.786102056503296 seconds
# Analyst-21 - Slowest analysis added in 2.258129119873047 seconds
# Analyst-21 - Average time adding analysis: 2.0221155881881714 seconds
# Analyst-22 - Fastest acquisition gotten in 0.4060230255126953 seconds
# Analyst-22 - Slowest acquisition gotten in 2.376136064529419 seconds
# Analyst-22 - Average time getting acquisitions: 1.3910795450210571 seconds
# Analyst-22 - Fastest analysis added in 1.1440653800964355 seconds
# Analyst-22 - Slowest analysis added in 1.2750730514526367 seconds
# Analyst-22 - Average time adding analysis: 1.2095692157745361 seconds
# Analyst-23 - Fastest acquisition gotten in 0.2850160598754883 seconds
# Analyst-23 - Slowest acquisition gotten in 2.2351279258728027 seconds
# Analyst-23 - Average time getting acquisitions: 1.2600719928741455 seconds
# Analyst-23 - Fastest analysis added in 1.5740900039672852 seconds
# Analyst-23 - Slowest analysis added in 2.3211328983306885 seconds
# Analyst-23 - Average time adding analysis: 1.9476114511489868 seconds
# Analyst-24 - Fastest acquisition gotten in 0.3850219249725342 seconds
# Analyst-24 - Slowest acquisition gotten in 2.259129285812378 seconds
# Analyst-24 - Average time getting acquisitions: 1.322075605392456 seconds
# Analyst-24 - Fastest analysis added in 2.046116828918457 seconds
# Analyst-24 - Slowest analysis added in 2.289130926132202 seconds
# Analyst-24 - Average time adding analysis: 2.1676238775253296 seconds
# Analyst-25 - Fastest acquisition gotten in 0.4130239486694336 seconds
# Analyst-25 - Slowest acquisition gotten in 2.246128559112549 seconds
# Analyst-25 - Average time getting acquisitions: 1.3295762538909912 seconds
# Analyst-25 - Fastest analysis added in 1.090062141418457 seconds
# Analyst-25 - Slowest analysis added in 2.41713809967041 seconds
# Analyst-25 - Average time adding analysis: 1.7536001205444336 seconds
# Analyst-26 - Fastest acquisition gotten in 0.43302464485168457 seconds
# Analyst-26 - Slowest acquisition gotten in 2.3411338329315186 seconds
# Analyst-26 - Average time getting acquisitions: 1.3870792388916016 seconds
# Analyst-26 - Fastest analysis added in 2.304131507873535 seconds
# Analyst-26 - Slowest analysis added in 2.3291332721710205 seconds
# Analyst-26 - Average time adding analysis: 2.316632390022278 seconds
# Analyst-27 - Fastest acquisition gotten in 0.3590207099914551 seconds
# Analyst-27 - Slowest acquisition gotten in 2.3241329193115234 seconds
# Analyst-27 - Average time getting acquisitions: 1.3415768146514893 seconds
# Analyst-27 - Fastest analysis added in 1.3340764045715332 seconds
# Analyst-27 - Slowest analysis added in 2.256129026412964 seconds
# Analyst-27 - Average time adding analysis: 1.7951027154922485 seconds
# Analyst-28 - Fastest acquisition gotten in 0.32701873779296875 seconds
# Analyst-28 - Slowest acquisition gotten in 2.2171268463134766 seconds
# Analyst-28 - Average time getting acquisitions: 1.2720727920532227 seconds
# Analyst-28 - Fastest analysis added in 0.5740325450897217 seconds
# Analyst-28 - Slowest analysis added in 1.1720669269561768 seconds
# Analyst-28 - Average time adding analysis: 0.8730497360229492 seconds
# Analyst-29 - Fastest acquisition gotten in 0.20601153373718262 seconds
# Analyst-29 - Slowest acquisition gotten in 2.3081321716308594 seconds
# Analyst-29 - Average time getting acquisitions: 1.257071852684021 seconds
# Analyst-29 - Fastest analysis added in 1.073061227798462 seconds
# Analyst-29 - Slowest analysis added in 1.3900794982910156 seconds
# Analyst-29 - Average time adding analysis: 1.2315703630447388 seconds
# Analyst-30 - Fastest acquisition gotten in 0.32301831245422363 seconds
# Analyst-30 - Slowest acquisition gotten in 2.156123399734497 seconds
# Analyst-30 - Average time getting acquisitions: 1.2395708560943604 seconds
# Analyst-30 - Fastest analysis added in 1.4940853118896484 seconds
# Analyst-30 - Slowest analysis added in 2.412137985229492 seconds
# Analyst-30 - Average time adding analysis: 1.9531116485595703 seconds
# Analyst-31 - Fastest acquisition gotten in 0.31801843643188477 seconds
# Analyst-31 - Slowest acquisition gotten in 2.147122859954834 seconds
# Analyst-31 - Average time getting acquisitions: 1.2325706481933594 seconds
# Analyst-31 - Fastest analysis added in 0.36202049255371094 seconds
# Analyst-31 - Slowest analysis added in 0.42702436447143555 seconds
# Analyst-31 - Average time adding analysis: 0.39452242851257324 seconds
# Analyst-32 - Fastest acquisition gotten in 0.45102572441101074 seconds
# Analyst-32 - Slowest acquisition gotten in 2.2471282482147217 seconds
# Analyst-32 - Average time getting acquisitions: 1.3490769863128662 seconds
# Analyst-32 - Fastest analysis added in 2.242128610610962 seconds
# Analyst-32 - Slowest analysis added in 2.38313627243042 seconds
# Analyst-32 - Average time adding analysis: 2.312632441520691 seconds
# Analyst-33 - Fastest acquisition gotten in 0.3430194854736328 seconds
# Analyst-33 - Slowest acquisition gotten in 2.171124219894409 seconds
# Analyst-33 - Average time getting acquisitions: 1.257071852684021 seconds
# Analyst-33 - Fastest analysis added in 0.5100290775299072 seconds
# Analyst-33 - Slowest analysis added in 1.4600837230682373 seconds
# Analyst-33 - Average time adding analysis: 0.9850564002990723 seconds
# Analyst-34 - Fastest acquisition gotten in 0.20101165771484375 seconds
# Analyst-34 - Slowest acquisition gotten in 2.279130220413208 seconds
# Analyst-34 - Average time getting acquisitions: 1.2400709390640259 seconds
# Analyst-34 - Fastest analysis added in 2.3141324520111084 seconds
# Analyst-34 - Slowest analysis added in 2.3241329193115234 seconds
# Analyst-34 - Average time adding analysis: 2.319132685661316 seconds
# Analyst-35 - Fastest acquisition gotten in 0.3450198173522949 seconds
# Analyst-35 - Slowest acquisition gotten in 2.150123119354248 seconds
# Analyst-35 - Average time getting acquisitions: 1.2475714683532715 seconds
# Analyst-35 - Fastest analysis added in 2.3551347255706787 seconds
# Analyst-35 - Slowest analysis added in 2.38313627243042 seconds
# Analyst-35 - Average time adding analysis: 2.3691354990005493 seconds
# Analyst-36 - Fastest acquisition gotten in 0.34201955795288086 seconds
# Analyst-36 - Slowest acquisition gotten in 2.13712215423584 seconds
# Analyst-36 - Average time getting acquisitions: 1.2395708560943604 seconds
# Analyst-36 - Fastest analysis added in 0.4350249767303467 seconds
# Analyst-36 - Slowest analysis added in 2.2061262130737305 seconds
# Analyst-36 - Average time adding analysis: 1.3205755949020386 seconds
# Analyst-37 - Fastest acquisition gotten in 0.43102478981018066 seconds
# Analyst-37 - Slowest acquisition gotten in 2.2231268882751465 seconds
# Analyst-37 - Average time getting acquisitions: 1.3270758390426636 seconds
# Analyst-37 - Fastest analysis added in 1.5990912914276123 seconds
# Analyst-37 - Slowest analysis added in 2.2021260261535645 seconds
# Analyst-37 - Average time adding analysis: 1.9006086587905884 seconds
# Analyst-38 - Fastest acquisition gotten in 0.32901883125305176 seconds
# Analyst-38 - Slowest acquisition gotten in 2.1161210536956787 seconds
# Analyst-38 - Average time getting acquisitions: 1.2225699424743652 seconds
# Analyst-38 - Fastest analysis added in 0.5350303649902344 seconds
# Analyst-38 - Slowest analysis added in 2.3501341342926025 seconds
# Analyst-38 - Average time adding analysis: 1.4425822496414185 seconds
# Analyst-39 - Fastest acquisition gotten in 0.2130122184753418 seconds
# Analyst-39 - Slowest acquisition gotten in 2.1081206798553467 seconds
# Analyst-39 - Average time getting acquisitions: 1.1605664491653442 seconds
# Analyst-39 - Fastest analysis added in 0.358020544052124 seconds
# Analyst-39 - Slowest analysis added in 2.538145065307617 seconds
# Analyst-39 - Average time adding analysis: 1.4480828046798706 seconds
# Analyst-40 - Fastest acquisition gotten in 0.35502028465270996 seconds
# Analyst-40 - Slowest acquisition gotten in 2.280130386352539 seconds
# Analyst-40 - Average time getting acquisitions: 1.3175753355026245 seconds
# Analyst-40 - Fastest analysis added in 1.2310705184936523 seconds
# Analyst-40 - Slowest analysis added in 1.5750901699066162 seconds
# Analyst-40 - Average time adding analysis: 1.4030803442001343 seconds
# Analyst-41 - Fastest acquisition gotten in 0.3500199317932129 seconds
# Analyst-41 - Slowest acquisition gotten in 2.1171212196350098 seconds
# Analyst-41 - Average time getting acquisitions: 1.2335705757141113 seconds
# Analyst-41 - Fastest analysis added in 1.3890793323516846 seconds
# Analyst-41 - Slowest analysis added in 2.253129005432129 seconds
# Analyst-41 - Average time adding analysis: 1.8211041688919067 seconds
# Analyst-42 - Fastest acquisition gotten in 0.36002039909362793 seconds
# Analyst-42 - Slowest acquisition gotten in 2.263129234313965 seconds
# Analyst-42 - Average time getting acquisitions: 1.3115748167037964 seconds
# Analyst-42 - Fastest analysis added in 1.319075584411621 seconds
# Analyst-42 - Slowest analysis added in 1.9581120014190674 seconds
# Analyst-42 - Average time adding analysis: 1.6385937929153442 seconds
# Analyst-43 - Fastest acquisition gotten in 0.3350191116333008 seconds
# Analyst-43 - Slowest acquisition gotten in 2.2401278018951416 seconds
# Analyst-43 - Average time getting acquisitions: 1.2875734567642212 seconds
# Analyst-43 - Fastest analysis added in 0.5570321083068848 seconds
# Analyst-43 - Slowest analysis added in 2.0561177730560303 seconds
# Analyst-43 - Average time adding analysis: 1.3065749406814575 seconds
# Analyst-44 - Fastest acquisition gotten in 0.28801655769348145 seconds
# Analyst-44 - Slowest acquisition gotten in 2.2161266803741455 seconds
# Analyst-44 - Average time getting acquisitions: 1.2520716190338135 seconds
# Analyst-44 - Fastest analysis added in 1.069061040878296 seconds
# Analyst-44 - Slowest analysis added in 2.494142532348633 seconds
# Analyst-44 - Average time adding analysis: 1.7816017866134644 seconds
# Analyst-45 - Fastest acquisition gotten in 0.2540144920349121 seconds
# Analyst-45 - Slowest acquisition gotten in 2.1941254138946533 seconds
# Analyst-45 - Average time getting acquisitions: 1.2240699529647827 seconds
# Analyst-45 - Fastest analysis added in 2.4391396045684814 seconds
# Analyst-45 - Slowest analysis added in 2.512143611907959 seconds
# Analyst-45 - Average time adding analysis: 2.47564160823822 seconds
# Analyst-46 - Fastest acquisition gotten in 0.4740269184112549 seconds
# Analyst-46 - Slowest acquisition gotten in 2.1881251335144043 seconds
# Analyst-46 - Average time getting acquisitions: 1.3310760259628296 seconds
# Analyst-46 - Fastest analysis added in 0.27501559257507324 seconds
# Analyst-46 - Slowest analysis added in 2.3501346111297607 seconds
# Analyst-46 - Average time adding analysis: 1.312575101852417 seconds
# Analyst-47 - Fastest acquisition gotten in 0.480027437210083 seconds
# Analyst-47 - Slowest acquisition gotten in 2.1701242923736572 seconds
# Analyst-47 - Average time getting acquisitions: 1.3250758647918701 seconds
# Analyst-47 - Fastest analysis added in 1.0440597534179688 seconds
# Analyst-47 - Slowest analysis added in 1.3760788440704346 seconds
# Analyst-47 - Average time adding analysis: 1.2100692987442017 seconds
# Analyst-48 - Fastest acquisition gotten in 0.350020170211792 seconds
# Analyst-48 - Slowest acquisition gotten in 2.0901198387145996 seconds
# Analyst-48 - Average time getting acquisitions: 1.2200700044631958 seconds
# Analyst-48 - Fastest analysis added in 1.452082872390747 seconds
# Analyst-48 - Slowest analysis added in 2.273130178451538 seconds
# Analyst-48 - Average time adding analysis: 1.8626065254211426 seconds
# Analyst-49 - Fastest acquisition gotten in 0.47502708435058594 seconds
# Analyst-49 - Slowest acquisition gotten in 2.037116289138794 seconds
# Analyst-49 - Average time getting acquisitions: 1.25607168674469 seconds
# Analyst-49 - Fastest analysis added in 0.5090289115905762 seconds
# Analyst-49 - Slowest analysis added in 2.257128953933716 seconds
# Analyst-49 - Average time adding analysis: 1.383078932762146 seconds
# MIN GET ACQ --> 0.1240072250366211
# AVG GET ACQ --> 1.2635322546958923
# MAX GET ACQ --> 2.376136064529419
# MIN ADD ANA --> 0.27501559257507324
# AVG ADD ANA --> 1.5761401391029357
# MAX ADD ANA --> 1.1740672588348389
# Add Analysis Test Finalized

# %% [markdown]
# ### Activating Plotly (scientific graphing library)

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Charts

# %%
num_analysts = ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"]

min_get_acq = [0.12300682067871094, 0.12300705909729004, 0.12300705909729004, 0.12300705909729004, 0.12700724601745605, 0.1240072250366211]
avg_get_acq = [0.1397079920768738, 0.14265818357467652, 0.16056919813156129, 0.21181210994720456, 0.4906280446052551, 1.2635322546958923]
max_get_acq = [0.39402246475219727, 0.2170124053955078, 0.38602209091186523, 0.6440370082855225, 1.3940796852111816, 2.376136064529419]
min_add_ana = [2.2181267738342285, 0.3110177516937256, 0.6170351505279541, 0.29401683807373047, 0.28801655769348145, 0.27501559257507324]
avg_add_ana = [2.252398822307587, 2.1576534008979795, 2.133221995830536, 1.9954841208457945, 1.8388752055168152, 1.5761401391029357]
max_add_ana = [2.3491342067718506, 2.633150815963745, 2.306131601333618, 2.3611347675323486, 2.303131580352783, 1.1740672588348389]

# %% [markdown]
# #### Get acquisition times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_get_acq,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_get_acq,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_get_acq,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when retrieving acquisition data w/ different number of analysts',
    xaxis=dict(title=dict(text="Number of analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="1880f3b3-3ac3-414a-942d-189ffd41d481" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1880f3b3-3ac3-414a-942d-189ffd41d481")) {
#                     Plotly.newPlot(
#                         '1880f3b3-3ac3-414a-942d-189ffd41d481',
#                         [{"name": "Minimum", "type": "bar", "uid": "eae69038-2b45-44e0-9113-ff0e37a2cc08", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.12300682067871094, 0.12300705909729004, 0.12300705909729004, 0.12300705909729004, 0.12700724601745605, 0.1240072250366211]}, {"name": "Average", "type": "bar", "uid": "ac303cd4-5226-4bee-aa2e-24095a3d3ced", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.1397079920768738, 0.14265818357467652, 0.16056919813156129, 0.21181210994720456, 0.4906280446052551, 1.2635322546958923]}, {"name": "Maximum", "type": "bar", "uid": "358b8d8c-dd48-43e8-acf1-2bee6b26f0ff", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.39402246475219727, 0.2170124053955078, 0.38602209091186523, 0.6440370082855225, 1.3940796852111816, 2.376136064529419]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when retrieving acquisition data w/ different number of analysts"}, "xaxis": {"title": {"text": "Number of analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1880f3b3-3ac3-414a-942d-189ffd41d481');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Add analysis times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_add_ana,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_add_ana,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_add_ana,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when executing tx AddAnalysis w/ different number of analysts',
    xaxis=dict(title=dict(text="Analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="bc65ac65-1eb1-4d5d-8807-2c0b48cdadce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bc65ac65-1eb1-4d5d-8807-2c0b48cdadce")) {
#                     Plotly.newPlot(
#                         'bc65ac65-1eb1-4d5d-8807-2c0b48cdadce',
#                         [{"name": "Minimum", "type": "bar", "uid": "e44446ea-41b9-40ab-9ddd-09e97ea08305", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.2181267738342285, 0.3110177516937256, 0.6170351505279541, 0.29401683807373047, 0.28801655769348145, 0.27501559257507324]}, {"name": "Average", "type": "bar", "uid": "8296a994-f435-43f6-a0dc-a0c4f905ac6c", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.252398822307587, 2.1576534008979795, 2.133221995830536, 1.9954841208457945, 1.8388752055168152, 1.5761401391029357]}, {"name": "Maximum", "type": "bar", "uid": "a94f88cf-3c4a-49c5-b10d-51727bed9aa0", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.3491342067718506, 2.633150815963745, 2.306131601333618, 2.3611347675323486, 2.303131580352783, 1.1740672588348389]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when executing tx AddAnalysis w/ different number of analysts"}, "xaxis": {"title": {"text": "Analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bc65ac65-1eb1-4d5d-8807-2c0b48cdadce');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
