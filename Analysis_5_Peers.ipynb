# %% [markdown]
# # Real case - Analyst times (5 Peers)

# %% [markdown]
# ### Imports

# %%
import threading
import requests
import json
import random
import plotly
import plotly.graph_objs as go
from analyst import *

# %% [markdown]
# ### Global variables

# %%
API_ENDPOINT = "http://35.205.21.76:3000/api/"
NS = "ertis.uma.nuclear"

# %% [markdown]
# ### Function

# %%
def addAnalysisTest(num_analysts, num_acqs):
    analyst_threads = []
    analysis_per_worker = int(num_acqs/num_analysts)
    
    # Check for next analysis id
    resource_url = f"{API_ENDPOINT}{NS}.Analysis"
    r = requests.get(resource_url)
    next_id = len(r.json()) + 1
    
    # Create threads
    for i in range(num_analysts):
        thread = Analyst(i, f"Analyst-{i}", analysis_per_worker, next_id+analysis_per_worker*i, API_ENDPOINT, NS)
        analyst_threads.append(thread)
        
    # Start threads
    for i in range(num_analysts):
        analyst_threads[i].start()
        
    # Join threads
    for i in range(num_analysts):
        analyst_threads[i].join()
        
    # Print results
    min_get = analyst_threads[0].min_get
    avg_get = analyst_threads[0].avg_get
    max_get = analyst_threads[0].max_get
    min_add = analyst_threads[0].min_add
    avg_add = analyst_threads[0].avg_add
    max_add = analyst_threads[0].max_add
    analyst_threads[0].printResults()
    for i in range(1, num_analysts):
        if analyst_threads[i].min_get < min_get:
            min_get = analyst_threads[i].min_get

        avg_get = avg_get + analyst_threads[i].avg_get

        if analyst_threads[i].max_get > max_get:
            max_get = analyst_threads[i].max_get
            
        if analyst_threads[i].min_add < min_add:
            min_add = analyst_threads[i].min_add
            
        avg_add = avg_add + analyst_threads[i].avg_add
        
        if analyst_threads[i].max_get > max_get:
            max_add = analyst_threads[i].max_add

        analyst_threads[i].printResults()

    print(f"MIN GET ACQ --> {min_get}")
    print(f"AVG GET ACQ --> {avg_get/num_analysts}")
    print(f"MAX GET ACQ --> {max_get}")
    print(f"MIN ADD ANA --> {min_add}")
    print(f"AVG ADD ANA --> {avg_add/num_analysts}")
    print(f"MAX ADD ANA --> {max_add}")

    print("Add Analysis Test Finalized")

# %% [markdown]
# ### Execution of the test (100 analysis to do) with one single analyst

# %%
addAnalysisTest(1, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started

# %% [markdown]
# ### Execution of the test (100 analysis to do) with two (2) analysts

# %%
addAnalysisTest(2, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
#
# Analyst Analyst-0 has finishedAnalyst Analyst-1 has finished
#
# Analyst-0 - Fastest acquisition gotten in 0.16200923919677734 seconds
# Analyst-0 - Slowest acquisition gotten in 0.22501301765441895 seconds
# Analyst-0 - Average time getting acquisitions: 0.17597005367279053 seconds
# Analyst-0 - Fastest analysis added in 2.252128839492798 seconds
# Analyst-0 - Slowest analysis added in 2.4611406326293945 seconds
# Analyst-0 - Average time adding analysis: 2.28971097946167 seconds
# Analyst-1 - Fastest acquisition gotten in 0.15600895881652832 seconds
# Analyst-1 - Slowest acquisition gotten in 0.23601365089416504 seconds
# Analyst-1 - Average time getting acquisitions: 0.17611009120941162 seconds
# Analyst-1 - Fastest analysis added in 2.258129119873047 seconds
# Analyst-1 - Slowest analysis added in 2.4521403312683105 seconds
# Analyst-1 - Average time adding analysis: 2.2898109483718874 seconds
# MIN GET ACQ --> 0.15600895881652832
# AVG GET ACQ --> 0.1760400724411011
# MAX GET ACQ --> 0.23601365089416504
# MIN ADD ANA --> 2.252128839492798
# AVG ADD ANA --> 2.2897609639167786
# MAX ADD ANA --> 2.4611406326293945
# Add Analysis Test Finalized
# TOTAL TIME --> 123.48606276512146

# %% [markdown]
# ### Execution of the test (100 analysis to do) with five (5) analysts

# %%
addAnalysisTest(5, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has started
#
# Analyst Analyst-2 has startedAnalyst Analyst-3 has started
# Analyst Analyst-4 has started
#
# Analyst Analyst-0 has finishedAnalyst Analyst-1 has finished
#
# Analyst Analyst-2 has finished
# Analyst Analyst-4 has finishedAnalyst Analyst-3 has finished
#
# Analyst-0 - Fastest acquisition gotten in 0.2670154571533203 seconds
# Analyst-0 - Slowest acquisition gotten in 0.5090289115905762 seconds
# Analyst-0 - Average time getting acquisitions: 0.32181841135025024 seconds
# Analyst-0 - Fastest analysis added in 2.16512393951416 seconds
# Analyst-0 - Slowest analysis added in 2.7161552906036377 seconds
# Analyst-0 - Average time adding analysis: 2.3885366201400755 seconds
# Analyst-1 - Fastest acquisition gotten in 0.16900968551635742 seconds
# Analyst-1 - Slowest acquisition gotten in 0.5260300636291504 seconds
# Analyst-1 - Average time getting acquisitions: 0.3063175678253174 seconds
# Analyst-1 - Fastest analysis added in 2.2081260681152344 seconds
# Analyst-1 - Slowest analysis added in 2.7141551971435547 seconds
# Analyst-1 - Average time adding analysis: 2.403987431526184 seconds
# Analyst-2 - Fastest acquisition gotten in 0.2720155715942383 seconds
# Analyst-2 - Slowest acquisition gotten in 0.5210297107696533 seconds
# Analyst-2 - Average time getting acquisitions: 0.3237184643745422 seconds
# Analyst-2 - Fastest analysis added in 2.1741247177124023 seconds
# Analyst-2 - Slowest analysis added in 2.6941542625427246 seconds
# Analyst-2 - Average time adding analysis: 2.385436499118805 seconds
# Analyst-3 - Fastest acquisition gotten in 0.17301011085510254 seconds
# Analyst-3 - Slowest acquisition gotten in 0.5040285587310791 seconds
# Analyst-3 - Average time getting acquisitions: 0.31891824007034303 seconds
# Analyst-3 - Fastest analysis added in 2.2001259326934814 seconds
# Analyst-3 - Slowest analysis added in 2.7111549377441406 seconds
# Analyst-3 - Average time adding analysis: 2.390836763381958 seconds
# Analyst-4 - Fastest acquisition gotten in 0.2560145854949951 seconds
# Analyst-4 - Slowest acquisition gotten in 0.5140292644500732 seconds
# Analyst-4 - Average time getting acquisitions: 0.317618203163147 seconds
# Analyst-4 - Fastest analysis added in 2.17812442779541 seconds
# Analyst-4 - Slowest analysis added in 2.6941540241241455 seconds
# Analyst-4 - Average time adding analysis: 2.391436767578125 seconds
# MIN GET ACQ --> 0.16900968551635742
# AVG GET ACQ --> 0.31767817735672
# MAX GET ACQ --> 0.5260300636291504
# MIN ADD ANA --> 2.16512393951416
# AVG ADD ANA --> 2.392046816349029
# MAX ADD ANA --> 2.7161552906036377
# Add Analysis Test Finalized
# TOTAL TIME --> 54.41011190414429

# %% [markdown]
# ### Execution of the test (100 analysis to do) with ten (10) analysts

# %%
addAnalysisTest(10, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has started
# Analyst Analyst-2 has started
# Analyst Analyst-3 has startedAnalyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has started
# Analyst Analyst-7 has started
#
# Analyst Analyst-8 has started
# Analyst Analyst-9 has started
# Analyst Analyst-7 has finishedAnalyst Analyst-8 has finished
# Analyst Analyst-4 has finished
# Analyst Analyst-6 has finished
# Analyst Analyst-2 has finished
# Analyst Analyst-3 has finished
#
# Analyst Analyst-1 has finished
# Analyst Analyst-5 has finishedAnalyst Analyst-9 has finished
# Analyst Analyst-0 has finished
#
# Analyst-0 - Fastest acquisition gotten in 0.4590263366699219 seconds
# Analyst-0 - Slowest acquisition gotten in 0.5770328044891357 seconds
# Analyst-0 - Average time getting acquisitions: 0.5049289464950562 seconds
# Analyst-0 - Fastest analysis added in 0.7400422096252441 seconds
# Analyst-0 - Slowest analysis added in 1.0650608539581299 seconds
# Analyst-0 - Average time adding analysis: 0.8694496631622315 seconds
# Analyst-1 - Fastest acquisition gotten in 0.4520258903503418 seconds
# Analyst-1 - Slowest acquisition gotten in 0.5700323581695557 seconds
# Analyst-1 - Average time getting acquisitions: 0.49962852001190183 seconds
# Analyst-1 - Fastest analysis added in 0.7540431022644043 seconds
# Analyst-1 - Slowest analysis added in 1.062060832977295 seconds
# Analyst-1 - Average time adding analysis: 0.8730499744415283 seconds
# Analyst-2 - Fastest acquisition gotten in 0.44902539253234863 seconds
# Analyst-2 - Slowest acquisition gotten in 0.5560317039489746 seconds
# Analyst-2 - Average time getting acquisitions: 0.5002285718917847 seconds
# Analyst-2 - Fastest analysis added in 0.7590432167053223 seconds
# Analyst-2 - Slowest analysis added in 1.083061933517456 seconds
# Analyst-2 - Average time adding analysis: 0.8719499111175537 seconds
# Analyst-3 - Fastest acquisition gotten in 0.46402668952941895 seconds
# Analyst-3 - Slowest acquisition gotten in 0.5680325031280518 seconds
# Analyst-3 - Average time getting acquisitions: 0.5153295040130615 seconds
# Analyst-3 - Fastest analysis added in 0.7230415344238281 seconds
# Analyst-3 - Slowest analysis added in 1.0390596389770508 seconds
# Analyst-3 - Average time adding analysis: 0.8546489000320434 seconds
# Analyst-4 - Fastest acquisition gotten in 0.4470255374908447 seconds
# Analyst-4 - Slowest acquisition gotten in 0.6060347557067871 seconds
# Analyst-4 - Average time getting acquisitions: 0.5049289226531982 seconds
# Analyst-4 - Fastest analysis added in 0.7600431442260742 seconds
# Analyst-4 - Slowest analysis added in 1.0290586948394775 seconds
# Analyst-4 - Average time adding analysis: 0.863849401473999 seconds
# Analyst-5 - Fastest acquisition gotten in 0.4670267105102539 seconds
# Analyst-5 - Slowest acquisition gotten in 0.604034423828125 seconds
# Analyst-5 - Average time getting acquisitions: 0.5201297044754029 seconds
# Analyst-5 - Fastest analysis added in 0.7680439949035645 seconds
# Analyst-5 - Slowest analysis added in 1.0180583000183105 seconds
# Analyst-5 - Average time adding analysis: 0.8483485460281373 seconds
# Analyst-6 - Fastest acquisition gotten in 0.474027156829834 seconds
# Analyst-6 - Slowest acquisition gotten in 0.5810332298278809 seconds
# Analyst-6 - Average time getting acquisitions: 0.5154294967651367 seconds
# Analyst-6 - Fastest analysis added in 0.7770445346832275 seconds
# Analyst-6 - Slowest analysis added in 1.0380594730377197 seconds
# Analyst-6 - Average time adding analysis: 0.8524487733840942 seconds
# Analyst-7 - Fastest acquisition gotten in 0.45702648162841797 seconds
# Analyst-7 - Slowest acquisition gotten in 0.598034143447876 seconds
# Analyst-7 - Average time getting acquisitions: 0.5051288843154907 seconds
# Analyst-7 - Fastest analysis added in 0.7900452613830566 seconds
# Analyst-7 - Slowest analysis added in 1.0200583934783936 seconds
# Analyst-7 - Average time adding analysis: 0.8614492893218995 seconds
# Analyst-8 - Fastest acquisition gotten in 0.4500255584716797 seconds
# Analyst-8 - Slowest acquisition gotten in 0.5860335826873779 seconds
# Analyst-8 - Average time getting acquisitions: 0.5109291553497315 seconds
# Analyst-8 - Fastest analysis added in 0.7660436630249023 seconds
# Analyst-8 - Slowest analysis added in 1.0190582275390625 seconds
# Analyst-8 - Average time adding analysis: 0.8546489000320434 seconds
# Analyst-9 - Fastest acquisition gotten in 0.44902586936950684 seconds
# Analyst-9 - Slowest acquisition gotten in 0.5280301570892334 seconds
# Analyst-9 - Average time getting acquisitions: 0.4912280797958374 seconds
# Analyst-9 - Fastest analysis added in 0.7770445346832275 seconds
# Analyst-9 - Slowest analysis added in 1.072061538696289 seconds
# Analyst-9 - Average time adding analysis: 0.8758501052856446 seconds
# MIN GET ACQ --> 0.4470255374908447
# AVG GET ACQ --> 0.5067889785766602
# MAX GET ACQ --> 0.6060347557067871
# MIN ADD ANA --> 0.7230415344238281
# AVG ADD ANA --> 0.8625693464279175
# MAX ADD ANA --> 1.0650608539581299
# Add Analysis Test Finalized
# TOTAL TIME --> 13.935796976089478

# %% [markdown]
# ### Execution of the test (100 analysis to do) with twenty five (25) analysts

# %%
addAnalysisTest(25, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has startedAnalyst Analyst-1 has startedAnalyst Analyst-2 has started
# Analyst Analyst-3 has started
#
#
# Analyst Analyst-4 has started
# Analyst Analyst-5 has started
# Analyst Analyst-6 has started
# Analyst Analyst-7 has startedAnalyst Analyst-8 has started
# Analyst Analyst-9 has started
# Analyst Analyst-10 has started
#
# Analyst Analyst-11 has startedAnalyst Analyst-12 has started
#
# Analyst Analyst-13 has started
# Analyst Analyst-14 has startedAnalyst Analyst-15 has started
#
# Analyst Analyst-16 has startedAnalyst Analyst-17 has started
#
# Analyst Analyst-18 has started
# Analyst Analyst-19 has startedAnalyst Analyst-20 has started
# Analyst Analyst-21 has started
#
# Analyst Analyst-22 has started
# Analyst Analyst-23 has started
# Analyst Analyst-24 has started
# Analyst Analyst-9 has finishedAnalyst Analyst-1 has finished
#
# Analyst Analyst-0 has finished
# Analyst Analyst-6 has finished
# Analyst Analyst-12 has finished
# Analyst Analyst-17 has finishedAnalyst Analyst-7 has finished
# Analyst Analyst-4 has finished
# Analyst Analyst-11 has finished
#
# Analyst Analyst-15 has finishedAnalyst Analyst-21 has finished
#
# Analyst Analyst-5 has finished
# Analyst Analyst-3 has finishedAnalyst Analyst-22 has finished
# Analyst Analyst-2 has finished
# Analyst Analyst-23 has finished
# Analyst Analyst-14 has finished
#
# Analyst Analyst-18 has finished
# Analyst Analyst-20 has finished
# Analyst Analyst-8 has finishedAnalyst Analyst-24 has finished
#
# Analyst Analyst-13 has finishedAnalyst Analyst-10 has finished
#
# Analyst Analyst-19 has finished
# Analyst Analyst-16 has finished
# Analyst-0 - Fastest acquisition gotten in 0.5400307178497314 seconds
# Analyst-0 - Slowest acquisition gotten in 0.9230527877807617 seconds
# Analyst-0 - Average time getting acquisitions: 0.7360420227050781 seconds
# Analyst-0 - Fastest analysis added in 1.6200926303863525 seconds
# Analyst-0 - Slowest analysis added in 3.10017728805542 seconds
# Analyst-0 - Average time adding analysis: 2.543145477771759 seconds
# Analyst-1 - Fastest acquisition gotten in 0.4540259838104248 seconds
# Analyst-1 - Slowest acquisition gotten in 0.8350474834442139 seconds
# Analyst-1 - Average time getting acquisitions: 0.6050344705581665 seconds
# Analyst-1 - Fastest analysis added in 1.652094841003418 seconds
# Analyst-1 - Slowest analysis added in 2.7171554565429688 seconds
# Analyst-1 - Average time adding analysis: 2.2943813800811768 seconds
# Analyst-2 - Fastest acquisition gotten in 0.4670267105102539 seconds
# Analyst-2 - Slowest acquisition gotten in 1.3770787715911865 seconds
# Analyst-2 - Average time getting acquisitions: 0.8432983160018921 seconds
# Analyst-2 - Fastest analysis added in 1.8201041221618652 seconds
# Analyst-2 - Slowest analysis added in 3.4241955280303955 seconds
# Analyst-2 - Average time adding analysis: 2.5648966431617737 seconds
# Analyst-3 - Fastest acquisition gotten in 0.4670267105102539 seconds
# Analyst-3 - Slowest acquisition gotten in 1.196068525314331 seconds
# Analyst-3 - Average time getting acquisitions: 0.7817948460578918 seconds
# Analyst-3 - Fastest analysis added in 1.9711127281188965 seconds
# Analyst-3 - Slowest analysis added in 3.449197292327881 seconds
# Analyst-3 - Average time adding analysis: 2.622649908065796 seconds
# Analyst-4 - Fastest acquisition gotten in 0.5240299701690674 seconds
# Analyst-4 - Slowest acquisition gotten in 1.3370764255523682 seconds
# Analyst-4 - Average time getting acquisitions: 0.9608049392700195 seconds
# Analyst-4 - Fastest analysis added in 1.7170982360839844 seconds
# Analyst-4 - Slowest analysis added in 2.864163637161255 seconds
# Analyst-4 - Average time adding analysis: 2.316132426261902 seconds
# Analyst-5 - Fastest acquisition gotten in 0.43802499771118164 seconds
# Analyst-5 - Slowest acquisition gotten in 1.3350763320922852 seconds
# Analyst-5 - Average time getting acquisitions: 0.8215469121932983 seconds
# Analyst-5 - Fastest analysis added in 1.8341050148010254 seconds
# Analyst-5 - Slowest analysis added in 3.448197364807129 seconds
# Analyst-5 - Average time adding analysis: 2.5791475772857666 seconds
# Analyst-6 - Fastest acquisition gotten in 0.43802523612976074 seconds
# Analyst-6 - Slowest acquisition gotten in 1.180067539215088 seconds
# Analyst-6 - Average time getting acquisitions: 0.7985457181930542 seconds
# Analyst-6 - Fastest analysis added in 1.9641125202178955 seconds
# Analyst-6 - Slowest analysis added in 2.966169595718384 seconds
# Analyst-6 - Average time adding analysis: 2.4693912267684937 seconds
# Analyst-7 - Fastest acquisition gotten in 0.4280245304107666 seconds
# Analyst-7 - Slowest acquisition gotten in 1.2660725116729736 seconds
# Analyst-7 - Average time getting acquisitions: 0.8047960996627808 seconds
# Analyst-7 - Fastest analysis added in 1.7020971775054932 seconds
# Analyst-7 - Slowest analysis added in 3.460197925567627 seconds
# Analyst-7 - Average time adding analysis: 2.4501399993896484 seconds
# Analyst-8 - Fastest acquisition gotten in 0.7940454483032227 seconds
# Analyst-8 - Slowest acquisition gotten in 1.3280761241912842 seconds
# Analyst-8 - Average time getting acquisitions: 1.09956294298172 seconds
# Analyst-8 - Fastest analysis added in 2.1031203269958496 seconds
# Analyst-8 - Slowest analysis added in 3.2611865997314453 seconds
# Analyst-8 - Average time adding analysis: 2.6764031052589417 seconds
# Analyst-9 - Fastest acquisition gotten in 0.5560317039489746 seconds
# Analyst-9 - Slowest acquisition gotten in 1.2840733528137207 seconds
# Analyst-9 - Average time getting acquisitions: 0.8557989597320557 seconds
# Analyst-9 - Fastest analysis added in 1.584090232849121 seconds
# Analyst-9 - Slowest analysis added in 2.8051602840423584 seconds
# Analyst-9 - Average time adding analysis: 2.015865206718445 seconds
# Analyst-10 - Fastest acquisition gotten in 0.3840219974517822 seconds
# Analyst-10 - Slowest acquisition gotten in 1.3610777854919434 seconds
# Analyst-10 - Average time getting acquisitions: 0.8265473246574402 seconds
# Analyst-10 - Fastest analysis added in 1.681096076965332 seconds
# Analyst-10 - Slowest analysis added in 4.449254751205444 seconds
# Analyst-10 - Average time adding analysis: 2.9454184770584106 seconds
# Analyst-11 - Fastest acquisition gotten in 0.46002650260925293 seconds
# Analyst-11 - Slowest acquisition gotten in 1.4590833187103271 seconds
# Analyst-11 - Average time getting acquisitions: 0.7372922301292419 seconds
# Analyst-11 - Fastest analysis added in 1.672095537185669 seconds
# Analyst-11 - Slowest analysis added in 4.351248741149902 seconds
# Analyst-11 - Average time adding analysis: 2.5146437287330627 seconds
# Analyst-12 - Fastest acquisition gotten in 0.5180294513702393 seconds
# Analyst-12 - Slowest acquisition gotten in 1.2610721588134766 seconds
# Analyst-12 - Average time getting acquisitions: 0.8900508880615234 seconds
# Analyst-12 - Fastest analysis added in 1.800102949142456 seconds
# Analyst-12 - Slowest analysis added in 2.9121663570404053 seconds
# Analyst-12 - Average time adding analysis: 2.3578848242759705 seconds
# Analyst-13 - Fastest acquisition gotten in 0.5440309047698975 seconds
# Analyst-13 - Slowest acquisition gotten in 1.2750728130340576 seconds
# Analyst-13 - Average time getting acquisitions: 0.9100520014762878 seconds
# Analyst-13 - Fastest analysis added in 2.5431454181671143 seconds
# Analyst-13 - Slowest analysis added in 3.33919095993042 seconds
# Analyst-13 - Average time adding analysis: 2.849913001060486 seconds
# Analyst-14 - Fastest acquisition gotten in 0.5420310497283936 seconds
# Analyst-14 - Slowest acquisition gotten in 1.2270700931549072 seconds
# Analyst-14 - Average time getting acquisitions: 0.8920509815216064 seconds
# Analyst-14 - Fastest analysis added in 1.2720727920532227 seconds
# Analyst-14 - Slowest analysis added in 3.324190139770508 seconds
# Analyst-14 - Average time adding analysis: 2.4713913798332214 seconds
# Analyst-15 - Fastest acquisition gotten in 0.4410252571105957 seconds
# Analyst-15 - Slowest acquisition gotten in 1.2270700931549072 seconds
# Analyst-15 - Average time getting acquisitions: 0.8765500783920288 seconds
# Analyst-15 - Fastest analysis added in 1.7120978832244873 seconds
# Analyst-15 - Slowest analysis added in 3.468198299407959 seconds
# Analyst-15 - Average time adding analysis: 2.48389208316803 seconds
# Analyst-16 - Fastest acquisition gotten in 0.37002110481262207 seconds
# Analyst-16 - Slowest acquisition gotten in 1.3600778579711914 seconds
# Analyst-16 - Average time getting acquisitions: 0.7972955703735352 seconds
# Analyst-16 - Fastest analysis added in 1.7040975093841553 seconds
# Analyst-16 - Slowest analysis added in 4.341248273849487 seconds
# Analyst-16 - Average time adding analysis: 2.9489187002182007 seconds
# Analyst-17 - Fastest acquisition gotten in 0.726041316986084 seconds
# Analyst-17 - Slowest acquisition gotten in 1.2440714836120605 seconds
# Analyst-17 - Average time getting acquisitions: 0.922802746295929 seconds
# Analyst-17 - Fastest analysis added in 1.7581007480621338 seconds
# Analyst-17 - Slowest analysis added in 3.1491799354553223 seconds
# Analyst-17 - Average time adding analysis: 2.3088820576667786 seconds
# Analyst-18 - Fastest acquisition gotten in 0.5610318183898926 seconds
# Analyst-18 - Slowest acquisition gotten in 1.2560718059539795 seconds
# Analyst-18 - Average time getting acquisitions: 0.9230527877807617 seconds
# Analyst-18 - Fastest analysis added in 1.2930738925933838 seconds
# Analyst-18 - Slowest analysis added in 3.2701873779296875 seconds
# Analyst-18 - Average time adding analysis: 2.43288916349411 seconds
# Analyst-19 - Fastest acquisition gotten in 0.38402223587036133 seconds
# Analyst-19 - Slowest acquisition gotten in 1.192068099975586 seconds
# Analyst-19 - Average time getting acquisitions: 0.7720441818237305 seconds
# Analyst-19 - Fastest analysis added in 1.691096544265747 seconds
# Analyst-19 - Slowest analysis added in 4.492257118225098 seconds
# Analyst-19 - Average time adding analysis: 2.965419590473175 seconds
# Analyst-20 - Fastest acquisition gotten in 0.7740442752838135 seconds
# Analyst-20 - Slowest acquisition gotten in 1.1960687637329102 seconds
# Analyst-20 - Average time getting acquisitions: 1.0493100881576538 seconds
# Analyst-20 - Fastest analysis added in 1.2560718059539795 seconds
# Analyst-20 - Slowest analysis added in 3.2571861743927 seconds
# Analyst-20 - Average time adding analysis: 2.302631676197052 seconds
# Analyst-21 - Fastest acquisition gotten in 0.45302605628967285 seconds
# Analyst-21 - Slowest acquisition gotten in 1.3270761966705322 seconds
# Analyst-21 - Average time getting acquisitions: 0.7475429177284241 seconds
# Analyst-21 - Fastest analysis added in 1.3800787925720215 seconds
# Analyst-21 - Slowest analysis added in 4.358249187469482 seconds
# Analyst-21 - Average time adding analysis: 2.5973984599113464 seconds
# Analyst-22 - Fastest acquisition gotten in 0.4500255584716797 seconds
# Analyst-22 - Slowest acquisition gotten in 1.1800673007965088 seconds
# Analyst-22 - Average time getting acquisitions: 0.777044415473938 seconds
# Analyst-22 - Fastest analysis added in 2.0851192474365234 seconds
# Analyst-22 - Slowest analysis added in 3.458197593688965 seconds
# Analyst-22 - Average time adding analysis: 2.5701470375061035 seconds
# Analyst-23 - Fastest acquisition gotten in 0.5500311851501465 seconds
# Analyst-23 - Slowest acquisition gotten in 1.192068338394165 seconds
# Analyst-23 - Average time getting acquisitions: 0.896551251411438 seconds
# Analyst-23 - Fastest analysis added in 1.2560720443725586 seconds
# Analyst-23 - Slowest analysis added in 3.3121895790100098 seconds
# Analyst-23 - Average time adding analysis: 2.449390232563019 seconds
# Analyst-24 - Fastest acquisition gotten in 0.8240470886230469 seconds
# Analyst-24 - Slowest acquisition gotten in 1.2920739650726318 seconds
# Analyst-24 - Average time getting acquisitions: 1.0908124446868896 seconds
# Analyst-24 - Fastest analysis added in 2.1941254138946533 seconds
# Analyst-24 - Slowest analysis added in 3.097177505493164 seconds
# Analyst-24 - Average time adding analysis: 2.6391510367393494 seconds
# MIN GET ACQ --> 0.37002110481262207
# AVG GET ACQ --> 0.8566490054130554
# MAX GET ACQ --> 1.4590833187103271
# MIN ADD ANA --> 1.2560718059539795
# AVG ADD ANA --> 2.534804975986481
# MAX ADD ANA --> 3.10017728805542
# Add Analysis Test Finalized
# TOTAL TIME --> 15.425882339477539

# %% [markdown]
# ### Execution of the test (100 analysis to do) with fifty (50) analysts

# %%
addAnalysisTest(50, 100) #Analysts, Analysis to do
# Out:
# Analyst Analyst-0 has started
# Analyst Analyst-1 has started
# Analyst Analyst-2 has startedAnalyst Analyst-3 has started
# Analyst Analyst-4 has started
#
# Analyst Analyst-5 has startedAnalyst Analyst-6 has started
#
# Analyst Analyst-7 has started
# Analyst Analyst-8 has started
# Analyst Analyst-9 has startedAnalyst Analyst-10 has started
#
# Analyst Analyst-11 has started
# Analyst Analyst-12 has started
# Analyst Analyst-13 has started
# Analyst Analyst-14 has started
# Analyst Analyst-15 has startedAnalyst Analyst-16 has started
# Analyst Analyst-17 has started
#
# Analyst Analyst-18 has started
# Analyst Analyst-19 has started
# Analyst Analyst-20 has started
# Analyst Analyst-21 has startedAnalyst Analyst-22 has started
# Analyst Analyst-23 has started
# Analyst Analyst-24 has startedAnalyst Analyst-25 has started
#
# Analyst Analyst-26 has started
#
# Analyst Analyst-27 has started
# Analyst Analyst-28 has started
# Analyst Analyst-29 has started
# Analyst Analyst-30 has started
# Analyst Analyst-31 has started
# Analyst Analyst-32 has started
# Analyst Analyst-33 has started
# Analyst Analyst-34 has started
# Analyst Analyst-35 has started
# Analyst Analyst-36 has started
# Analyst Analyst-37 has started
# Analyst Analyst-38 has started
# Analyst Analyst-39 has started
# Analyst Analyst-40 has started
# Analyst Analyst-41 has startedAnalyst Analyst-42 has started
# Analyst Analyst-43 has started
# Analyst Analyst-44 has started
#
# Analyst Analyst-45 has startedAnalyst Analyst-46 has started
#
# Analyst Analyst-47 has started
# Analyst Analyst-48 has started
# Analyst Analyst-49 has started
# Analyst Analyst-12 has finished
# Analyst Analyst-13 has finishedAnalyst Analyst-2 has finished
# Analyst Analyst-10 has finished
#
# Analyst Analyst-3 has finished
# Analyst Analyst-1 has finished
# Analyst Analyst-8 has finishedAnalyst Analyst-11 has finished
#
# Analyst Analyst-0 has finished
# Analyst Analyst-6 has finished
# Analyst Analyst-4 has finishedAnalyst Analyst-15 has finished
# Analyst Analyst-18 has finished
# Analyst Analyst-16 has finished
#
# Analyst Analyst-20 has finishedAnalyst Analyst-24 has finished
#
# Analyst Analyst-5 has finishedAnalyst Analyst-14 has finished
#
# Analyst Analyst-7 has finishedAnalyst Analyst-9 has finished
#
# Analyst Analyst-21 has finishedAnalyst Analyst-30 has finished
#
# Analyst Analyst-23 has finishedAnalyst Analyst-25 has finished
#
# Analyst Analyst-49 has finished
# Analyst Analyst-17 has finished
# Analyst Analyst-32 has finished
# Analyst Analyst-26 has finished
# Analyst Analyst-19 has finishedAnalyst Analyst-22 has finished
#
# Analyst Analyst-28 has finished
# Analyst Analyst-43 has finishedAnalyst Analyst-29 has finishedAnalyst Analyst-27 has finished
# Analyst Analyst-33 has finished
#
# Analyst Analyst-34 has finishedAnalyst Analyst-31 has finished
#
# Analyst Analyst-35 has finished
#
# Analyst Analyst-37 has finished
# Analyst Analyst-39 has finished
# Analyst Analyst-48 has finishedAnalyst Analyst-46 has finishedAnalyst Analyst-40 has finished
# Analyst Analyst-36 has finished
# Analyst Analyst-44 has finished
# Analyst Analyst-42 has finished
# Analyst Analyst-41 has finishedAnalyst Analyst-47 has finished
# Analyst Analyst-45 has finished
#
#
#
# Analyst Analyst-38 has finished
# Analyst-0 - Fastest acquisition gotten in 0.714040994644165 seconds
# Analyst-0 - Slowest acquisition gotten in 1.787102222442627 seconds
# Analyst-0 - Average time getting acquisitions: 1.250571608543396 seconds
# Analyst-0 - Fastest analysis added in 3.9112236499786377 seconds
# Analyst-0 - Slowest analysis added in 5.874336004257202 seconds
# Analyst-0 - Average time adding analysis: 4.89277982711792 seconds
# Analyst-1 - Fastest acquisition gotten in 0.6830389499664307 seconds
# Analyst-1 - Slowest acquisition gotten in 1.8921082019805908 seconds
# Analyst-1 - Average time getting acquisitions: 1.2875735759735107 seconds
# Analyst-1 - Fastest analysis added in 3.816218376159668 seconds
# Analyst-1 - Slowest analysis added in 5.876336097717285 seconds
# Analyst-1 - Average time adding analysis: 4.846277236938477 seconds
# Analyst-2 - Fastest acquisition gotten in 0.6400365829467773 seconds
# Analyst-2 - Slowest acquisition gotten in 1.7210984230041504 seconds
# Analyst-2 - Average time getting acquisitions: 1.1805675029754639 seconds
# Analyst-2 - Fastest analysis added in 3.938225269317627 seconds
# Analyst-2 - Slowest analysis added in 5.935339450836182 seconds
# Analyst-2 - Average time adding analysis: 4.936782360076904 seconds
# Analyst-3 - Fastest acquisition gotten in 0.6550374031066895 seconds
# Analyst-3 - Slowest acquisition gotten in 1.7150981426239014 seconds
# Analyst-3 - Average time getting acquisitions: 1.1850677728652954 seconds
# Analyst-3 - Fastest analysis added in 3.932224988937378 seconds
# Analyst-3 - Slowest analysis added in 5.92733907699585 seconds
# Analyst-3 - Average time adding analysis: 4.929782032966614 seconds
# Analyst-4 - Fastest acquisition gotten in 0.8770501613616943 seconds
# Analyst-4 - Slowest acquisition gotten in 2.2391281127929688 seconds
# Analyst-4 - Average time getting acquisitions: 1.5580891370773315 seconds
# Analyst-4 - Fastest analysis added in 4.337247848510742 seconds
# Analyst-4 - Slowest analysis added in 5.361306667327881 seconds
# Analyst-4 - Average time adding analysis: 4.8492772579193115 seconds
# Analyst-5 - Fastest acquisition gotten in 0.9880564212799072 seconds
# Analyst-5 - Slowest acquisition gotten in 2.172124147415161 seconds
# Analyst-5 - Average time getting acquisitions: 1.5800902843475342 seconds
# Analyst-5 - Fastest analysis added in 4.3712499141693115 seconds
# Analyst-5 - Slowest analysis added in 5.247300148010254 seconds
# Analyst-5 - Average time adding analysis: 4.809275031089783 seconds
# Analyst-6 - Fastest acquisition gotten in 0.6690380573272705 seconds
# Analyst-6 - Slowest acquisition gotten in 2.0031144618988037 seconds
# Analyst-6 - Average time getting acquisitions: 1.336076259613037 seconds
# Analyst-6 - Fastest analysis added in 3.6222071647644043 seconds
# Analyst-6 - Slowest analysis added in 5.922338962554932 seconds
# Analyst-6 - Average time adding analysis: 4.772273063659668 seconds
# Analyst-7 - Fastest acquisition gotten in 1.069061040878296 seconds
# Analyst-7 - Slowest acquisition gotten in 2.1951253414154053 seconds
# Analyst-7 - Average time getting acquisitions: 1.6320931911468506 seconds
# Analyst-7 - Fastest analysis added in 4.363249778747559 seconds
# Analyst-7 - Slowest analysis added in 5.172295808792114 seconds
# Analyst-7 - Average time adding analysis: 4.767772793769836 seconds
# Analyst-8 - Fastest acquisition gotten in 0.6680383682250977 seconds
# Analyst-8 - Slowest acquisition gotten in 2.1041202545166016 seconds
# Analyst-8 - Average time getting acquisitions: 1.3860793113708496 seconds
# Analyst-8 - Fastest analysis added in 3.5212013721466064 seconds
# Analyst-8 - Slowest analysis added in 5.884336471557617 seconds
# Analyst-8 - Average time adding analysis: 4.702768921852112 seconds
# Analyst-9 - Fastest acquisition gotten in 0.9430537223815918 seconds
# Analyst-9 - Slowest acquisition gotten in 2.1081204414367676 seconds
# Analyst-9 - Average time getting acquisitions: 1.5255870819091797 seconds
# Analyst-9 - Fastest analysis added in 4.396251678466797 seconds
# Analyst-9 - Slowest analysis added in 5.3153040409088135 seconds
# Analyst-9 - Average time adding analysis: 4.855777859687805 seconds
# Analyst-10 - Fastest acquisition gotten in 0.6970398426055908 seconds
# Analyst-10 - Slowest acquisition gotten in 2.0871193408966064 seconds
# Analyst-10 - Average time getting acquisitions: 1.3920795917510986 seconds
# Analyst-10 - Fastest analysis added in 3.5142009258270264 seconds
# Analyst-10 - Slowest analysis added in 5.849334716796875 seconds
# Analyst-10 - Average time adding analysis: 4.681767821311951 seconds
# Analyst-11 - Fastest acquisition gotten in 0.6450369358062744 seconds
# Analyst-11 - Slowest acquisition gotten in 2.034116506576538 seconds
# Analyst-11 - Average time getting acquisitions: 1.3395767211914062 seconds
# Analyst-11 - Fastest analysis added in 3.5532033443450928 seconds
# Analyst-11 - Slowest analysis added in 5.9243385791778564 seconds
# Analyst-11 - Average time adding analysis: 4.738770961761475 seconds
# Analyst-12 - Fastest acquisition gotten in 0.7030398845672607 seconds
# Analyst-12 - Slowest acquisition gotten in 2.0021142959594727 seconds
# Analyst-12 - Average time getting acquisitions: 1.3525770902633667 seconds
# Analyst-12 - Fastest analysis added in 3.589205503463745 seconds
# Analyst-12 - Slowest analysis added in 5.830333709716797 seconds
# Analyst-12 - Average time adding analysis: 4.709769606590271 seconds
# Analyst-13 - Fastest acquisition gotten in 0.6860394477844238 seconds
# Analyst-13 - Slowest acquisition gotten in 2.0841193199157715 seconds
# Analyst-13 - Average time getting acquisitions: 1.3850793838500977 seconds
# Analyst-13 - Fastest analysis added in 3.5092005729675293 seconds
# Analyst-13 - Slowest analysis added in 5.856334924697876 seconds
# Analyst-13 - Average time adding analysis: 4.682767748832703 seconds
# Analyst-14 - Fastest acquisition gotten in 1.074061393737793 seconds
# Analyst-14 - Slowest acquisition gotten in 2.2161271572113037 seconds
# Analyst-14 - Average time getting acquisitions: 1.6450942754745483 seconds
# Analyst-14 - Fastest analysis added in 4.280244588851929 seconds
# Analyst-14 - Slowest analysis added in 5.167295694351196 seconds
# Analyst-14 - Average time adding analysis: 4.7237701416015625 seconds
# Analyst-15 - Fastest acquisition gotten in 0.8630495071411133 seconds
# Analyst-15 - Slowest acquisition gotten in 2.2271273136138916 seconds
# Analyst-15 - Average time getting acquisitions: 1.5450884103775024 seconds
# Analyst-15 - Fastest analysis added in 4.2422425746917725 seconds
# Analyst-15 - Slowest analysis added in 5.371307134628296 seconds
# Analyst-15 - Average time adding analysis: 4.806774854660034 seconds
# Analyst-16 - Fastest acquisition gotten in 0.9310531616210938 seconds
# Analyst-16 - Slowest acquisition gotten in 2.300131320953369 seconds
# Analyst-16 - Average time getting acquisitions: 1.6155922412872314 seconds
# Analyst-16 - Fastest analysis added in 4.19323992729187 seconds
# Analyst-16 - Slowest analysis added in 5.296303033828735 seconds
# Analyst-16 - Average time adding analysis: 4.744771480560303 seconds
# Analyst-17 - Fastest acquisition gotten in 0.7420423030853271 seconds
# Analyst-17 - Slowest acquisition gotten in 2.4641408920288086 seconds
# Analyst-17 - Average time getting acquisitions: 1.6030915975570679 seconds
# Analyst-17 - Fastest analysis added in 4.144237041473389 seconds
# Analyst-17 - Slowest analysis added in 5.716326951980591 seconds
# Analyst-17 - Average time adding analysis: 4.93028199672699 seconds
# Analyst-18 - Fastest acquisition gotten in 0.9260528087615967 seconds
# Analyst-18 - Slowest acquisition gotten in 2.2341275215148926 seconds
# Analyst-18 - Average time getting acquisitions: 1.5800901651382446 seconds
# Analyst-18 - Fastest analysis added in 4.2382426261901855 seconds
# Analyst-18 - Slowest analysis added in 5.3093037605285645 seconds
# Analyst-18 - Average time adding analysis: 4.773773193359375 seconds
# Analyst-19 - Fastest acquisition gotten in 0.8740501403808594 seconds
# Analyst-19 - Slowest acquisition gotten in 2.4391393661499023 seconds
# Analyst-19 - Average time getting acquisitions: 1.6565947532653809 seconds
# Analyst-19 - Fastest analysis added in 4.0062291622161865 seconds
# Analyst-19 - Slowest analysis added in 5.745328664779663 seconds
# Analyst-19 - Average time adding analysis: 4.875778913497925 seconds
# Analyst-20 - Fastest acquisition gotten in 0.9930567741394043 seconds
# Analyst-20 - Slowest acquisition gotten in 2.2181267738342285 seconds
# Analyst-20 - Average time getting acquisitions: 1.6055917739868164 seconds
# Analyst-20 - Fastest analysis added in 4.256243467330933 seconds
# Analyst-20 - Slowest analysis added in 5.230299234390259 seconds
# Analyst-20 - Average time adding analysis: 4.743271350860596 seconds
# Analyst-21 - Fastest acquisition gotten in 0.7360420227050781 seconds
# Analyst-21 - Slowest acquisition gotten in 2.4371395111083984 seconds
# Analyst-21 - Average time getting acquisitions: 1.5865907669067383 seconds
# Analyst-21 - Fastest analysis added in 4.129236221313477 seconds
# Analyst-21 - Slowest analysis added in 5.714326858520508 seconds
# Analyst-21 - Average time adding analysis: 4.921781539916992 seconds
# Analyst-22 - Fastest acquisition gotten in 0.7670438289642334 seconds
# Analyst-22 - Slowest acquisition gotten in 2.4501402378082275 seconds
# Analyst-22 - Average time getting acquisitions: 1.6085920333862305 seconds
# Analyst-22 - Fastest analysis added in 4.101234674453735 seconds
# Analyst-22 - Slowest analysis added in 5.733327865600586 seconds
# Analyst-22 - Average time adding analysis: 4.917281270027161 seconds
# Analyst-23 - Fastest acquisition gotten in 0.7390422821044922 seconds
# Analyst-23 - Slowest acquisition gotten in 2.607149362564087 seconds
# Analyst-23 - Average time getting acquisitions: 1.6730958223342896 seconds
# Analyst-23 - Fastest analysis added in 4.1242358684539795 seconds
# Analyst-23 - Slowest analysis added in 5.556317567825317 seconds
# Analyst-23 - Average time adding analysis: 4.840276718139648 seconds
# Analyst-24 - Fastest acquisition gotten in 0.9240531921386719 seconds
# Analyst-24 - Slowest acquisition gotten in 2.2581288814544678 seconds
# Analyst-24 - Average time getting acquisitions: 1.5910910367965698 seconds
# Analyst-24 - Fastest analysis added in 4.188239574432373 seconds
# Analyst-24 - Slowest analysis added in 5.310303688049316 seconds
# Analyst-24 - Average time adding analysis: 4.749271631240845 seconds
# Analyst-25 - Fastest acquisition gotten in 0.7610435485839844 seconds
# Analyst-25 - Slowest acquisition gotten in 2.5491459369659424 seconds
# Analyst-25 - Average time getting acquisitions: 1.6550947427749634 seconds
# Analyst-25 - Fastest analysis added in 4.103234529495239 seconds
# Analyst-25 - Slowest analysis added in 5.608320713043213 seconds
# Analyst-25 - Average time adding analysis: 4.855777621269226 seconds
# Analyst-26 - Fastest acquisition gotten in 0.7540433406829834 seconds
# Analyst-26 - Slowest acquisition gotten in 2.4181385040283203 seconds
# Analyst-26 - Average time getting acquisitions: 1.5860909223556519 seconds
# Analyst-26 - Fastest analysis added in 4.1182355880737305 seconds
# Analyst-26 - Slowest analysis added in 5.740328073501587 seconds
# Analyst-26 - Average time adding analysis: 4.929281830787659 seconds
# Analyst-27 - Fastest acquisition gotten in 1.075061559677124 seconds
# Analyst-27 - Slowest acquisition gotten in 2.6811535358428955 seconds
# Analyst-27 - Average time getting acquisitions: 1.8781075477600098 seconds
# Analyst-27 - Fastest analysis added in 2.979170322418213 seconds
# Analyst-27 - Slowest analysis added in 6.565375328063965 seconds
# Analyst-27 - Average time adding analysis: 4.772272825241089 seconds
# Analyst-28 - Fastest acquisition gotten in 0.8770503997802734 seconds
# Analyst-28 - Slowest acquisition gotten in 2.654151678085327 seconds
# Analyst-28 - Average time getting acquisitions: 1.7656010389328003 seconds
# Analyst-28 - Fastest analysis added in 3.1661810874938965 seconds
# Analyst-28 - Slowest analysis added in 6.565375328063965 seconds
# Analyst-28 - Average time adding analysis: 4.865778207778931 seconds
# Analyst-29 - Fastest acquisition gotten in 0.9140522480010986 seconds
# Analyst-29 - Slowest acquisition gotten in 2.631150245666504 seconds
# Analyst-29 - Average time getting acquisitions: 1.7726012468338013 seconds
# Analyst-29 - Fastest analysis added in 3.1421799659729004 seconds
# Analyst-29 - Slowest analysis added in 6.59037709236145 seconds
# Analyst-29 - Average time adding analysis: 4.866278529167175 seconds
# Analyst-30 - Fastest acquisition gotten in 0.7560434341430664 seconds
# Analyst-30 - Slowest acquisition gotten in 2.5801477432250977 seconds
# Analyst-30 - Average time getting acquisitions: 1.668095588684082 seconds
# Analyst-30 - Fastest analysis added in 4.076233148574829 seconds
# Analyst-30 - Slowest analysis added in 5.5623180866241455 seconds
# Analyst-30 - Average time adding analysis: 4.819275617599487 seconds
# Analyst-31 - Fastest acquisition gotten in 1.0500600337982178 seconds
# Analyst-31 - Slowest acquisition gotten in 2.607149362564087 seconds
# Analyst-31 - Average time getting acquisitions: 1.8286046981811523 seconds
# Analyst-31 - Fastest analysis added in 2.987170696258545 seconds
# Analyst-31 - Slowest analysis added in 6.634379625320435 seconds
# Analyst-31 - Average time adding analysis: 4.81077516078949 seconds
# Analyst-32 - Fastest acquisition gotten in 0.849048376083374 seconds
# Analyst-32 - Slowest acquisition gotten in 2.392136573791504 seconds
# Analyst-32 - Average time getting acquisitions: 1.620592474937439 seconds
# Analyst-32 - Fastest analysis added in 4.018229961395264 seconds
# Analyst-32 - Slowest analysis added in 5.739328384399414 seconds
# Analyst-32 - Average time adding analysis: 4.878779172897339 seconds
# Analyst-33 - Fastest acquisition gotten in 1.1050631999969482 seconds
# Analyst-33 - Slowest acquisition gotten in 2.633150577545166 seconds
# Analyst-33 - Average time getting acquisitions: 1.8691068887710571 seconds
# Analyst-33 - Fastest analysis added in 2.9301674365997314 seconds
# Analyst-33 - Slowest analysis added in 6.601377725601196 seconds
# Analyst-33 - Average time adding analysis: 4.765772581100464 seconds
# Analyst-34 - Fastest acquisition gotten in 1.0190579891204834 seconds
# Analyst-34 - Slowest acquisition gotten in 2.6651525497436523 seconds
# Analyst-34 - Average time getting acquisitions: 1.8421052694320679 seconds
# Analyst-34 - Fastest analysis added in 3.0451743602752686 seconds
# Analyst-34 - Slowest analysis added in 6.533373832702637 seconds
# Analyst-34 - Average time adding analysis: 4.789274096488953 seconds
# Analyst-35 - Fastest acquisition gotten in 0.9440538883209229 seconds
# Analyst-35 - Slowest acquisition gotten in 2.614149332046509 seconds
# Analyst-35 - Average time getting acquisitions: 1.7791016101837158 seconds
# Analyst-35 - Fastest analysis added in 3.120178461074829 seconds
# Analyst-35 - Slowest analysis added in 6.582376480102539 seconds
# Analyst-35 - Average time adding analysis: 4.851277470588684 seconds
# Analyst-36 - Fastest acquisition gotten in 0.8210465908050537 seconds
# Analyst-36 - Slowest acquisition gotten in 2.882164716720581 seconds
# Analyst-36 - Average time getting acquisitions: 1.8516056537628174 seconds
# Analyst-36 - Fastest analysis added in 2.1151208877563477 seconds
# Analyst-36 - Slowest analysis added in 7.6974403858184814 seconds
# Analyst-36 - Average time adding analysis: 4.9062806367874146 seconds
# Analyst-37 - Fastest acquisition gotten in 1.068061351776123 seconds
# Analyst-37 - Slowest acquisition gotten in 2.7941598892211914 seconds
# Analyst-37 - Average time getting acquisitions: 1.9311106204986572 seconds
# Analyst-37 - Fastest analysis added in 2.9651691913604736 seconds
# Analyst-37 - Slowest analysis added in 6.425367593765259 seconds
# Analyst-37 - Average time adding analysis: 4.695268392562866 seconds
# Analyst-38 - Fastest acquisition gotten in 1.0500600337982178 seconds
# Analyst-38 - Slowest acquisition gotten in 2.625150203704834 seconds
# Analyst-38 - Average time getting acquisitions: 1.8376051187515259 seconds
# Analyst-38 - Fastest analysis added in 1.907109022140503 seconds
# Analyst-38 - Slowest analysis added in 7.937453746795654 seconds
# Analyst-38 - Average time adding analysis: 4.922281384468079 seconds
# Analyst-39 - Fastest acquisition gotten in 1.1320645809173584 seconds
# Analyst-39 - Slowest acquisition gotten in 2.8191614151000977 seconds
# Analyst-39 - Average time getting acquisitions: 1.975612998008728 seconds
# Analyst-39 - Fastest analysis added in 2.9251675605773926 seconds
# Analyst-39 - Slowest analysis added in 6.364364147186279 seconds
# Analyst-39 - Average time adding analysis: 4.644765853881836 seconds
# Analyst-40 - Fastest acquisition gotten in 1.0090577602386475 seconds
# Analyst-40 - Slowest acquisition gotten in 2.8021600246429443 seconds
# Analyst-40 - Average time getting acquisitions: 1.905608892440796 seconds
# Analyst-40 - Fastest analysis added in 1.920109748840332 seconds
# Analyst-40 - Slowest analysis added in 7.761444091796875 seconds
# Analyst-40 - Average time adding analysis: 4.8407769203186035 seconds
# Analyst-41 - Fastest acquisition gotten in 0.9840564727783203 seconds
# Analyst-41 - Slowest acquisition gotten in 3.1581807136535645 seconds
# Analyst-41 - Average time getting acquisitions: 2.0711185932159424 seconds
# Analyst-41 - Fastest analysis added in 1.938110589981079 seconds
# Analyst-41 - Slowest analysis added in 7.414423942565918 seconds
# Analyst-41 - Average time adding analysis: 4.6762672662734985 seconds
# Analyst-42 - Fastest acquisition gotten in 1.0370593070983887 seconds
# Analyst-42 - Slowest acquisition gotten in 3.117178440093994 seconds
# Analyst-42 - Average time getting acquisitions: 2.0771188735961914 seconds
# Analyst-42 - Fastest analysis added in 1.8761072158813477 seconds
# Analyst-42 - Slowest analysis added in 7.461426734924316 seconds
# Analyst-42 - Average time adding analysis: 4.668766975402832 seconds
# Analyst-43 - Fastest acquisition gotten in 1.0150578022003174 seconds
# Analyst-43 - Slowest acquisition gotten in 2.896165609359741 seconds
# Analyst-43 - Average time getting acquisitions: 1.9556117057800293 seconds
# Analyst-43 - Fastest analysis added in 3.0301735401153564 seconds
# Analyst-43 - Slowest analysis added in 6.2693586349487305 seconds
# Analyst-43 - Average time adding analysis: 4.6497660875320435 seconds
# Analyst-44 - Fastest acquisition gotten in 1.0390594005584717 seconds
# Analyst-44 - Slowest acquisition gotten in 3.0431742668151855 seconds
# Analyst-44 - Average time getting acquisitions: 2.0411168336868286 seconds
# Analyst-44 - Fastest analysis added in 1.8911082744598389 seconds
# Analyst-44 - Slowest analysis added in 7.50442910194397 seconds
# Analyst-44 - Average time adding analysis: 4.697768688201904 seconds
# Analyst-45 - Fastest acquisition gotten in 0.9820561408996582 seconds
# Analyst-45 - Slowest acquisition gotten in 3.0501744747161865 seconds
# Analyst-45 - Average time getting acquisitions: 2.0161153078079224 seconds
# Analyst-45 - Fastest analysis added in 1.9601120948791504 seconds
# Analyst-45 - Slowest analysis added in 7.483428239822388 seconds
# Analyst-45 - Average time adding analysis: 4.721770167350769 seconds
# Analyst-46 - Fastest acquisition gotten in 1.0350592136383057 seconds
# Analyst-46 - Slowest acquisition gotten in 3.0731759071350098 seconds
# Analyst-46 - Average time getting acquisitions: 2.0541175603866577 seconds
# Analyst-46 - Fastest analysis added in 1.8961083889007568 seconds
# Analyst-46 - Slowest analysis added in 7.460426568984985 seconds
# Analyst-46 - Average time adding analysis: 4.678267478942871 seconds
# Analyst-47 - Fastest acquisition gotten in 0.9570550918579102 seconds
# Analyst-47 - Slowest acquisition gotten in 2.987170696258545 seconds
# Analyst-47 - Average time getting acquisitions: 1.9721128940582275 seconds
# Analyst-47 - Fastest analysis added in 1.9821131229400635 seconds
# Analyst-47 - Slowest analysis added in 7.545431613922119 seconds
# Analyst-47 - Average time adding analysis: 4.763772368431091 seconds
# Analyst-48 - Fastest acquisition gotten in 0.9270529747009277 seconds
# Analyst-48 - Slowest acquisition gotten in 2.7911598682403564 seconds
# Analyst-48 - Average time getting acquisitions: 1.859106421470642 seconds
# Analyst-48 - Fastest analysis added in 1.9981143474578857 seconds
# Analyst-48 - Slowest analysis added in 7.730442047119141 seconds
# Analyst-48 - Average time adding analysis: 4.864278197288513 seconds
# Analyst-49 - Fastest acquisition gotten in 0.7520430088043213 seconds
# Analyst-49 - Slowest acquisition gotten in 2.38313627243042 seconds
# Analyst-49 - Average time getting acquisitions: 1.5675896406173706 seconds
# Analyst-49 - Fastest analysis added in 4.137236595153809 seconds
# Analyst-49 - Slowest analysis added in 5.634322166442871 seconds
# Analyst-49 - Average time adding analysis: 4.88577938079834 seconds
# MIN GET ACQ --> 0.6400365829467773
# AVG GET ACQ --> 1.6696454906463623
# MAX GET ACQ --> 3.1581807136535645
# MIN ADD ANA --> 1.8761072158813477
# AVG ADD ANA --> 4.800464570522308
# MAX ADD ANA --> 5.874336004257202
# Add Analysis Test Finalized
# TOTAL TIME --> 14.296817779541016

# %% [markdown]
# ### Activating Plotly (scientific graphing library)

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Charts

# %%
num_analysts = ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"]

min_get_acq = [0.12300729751586914, 0.15600895881652832, 0.16900968551635742, 0.4470255374908447, 0.37002110481262207, 0.640036582946777]
avg_get_acq = [0.13422767162323, 0.1760400724411011, 0.31767817735672, 0.5067889785766602, 0.8566490054130554, 1.6696454906463623]
max_get_acq = [0.20601201057434082, 0.23601365089416504, 0.5260300636291504, 0.6060347557067871, 1.4590833187103271, 3.1581807136535645]
min_add_ana = [2.2031259536743164, 2.252128839492798, 2.16512393951416, 0.7230415344238281, 1.2560718059539795, 1.8761072158813477]
avg_add_ana = [2.2285774636268614, 2.2897609639167786, 2.392046816349029, 0.8625693464279175, 2.534804975986481, 4.800464570522308]
max_add_ana = [2.3471343517303467, 2.4611406326293945, 2.7161552906036377, 1.0650608539581299, 3.10017728805542, 5.874336004257202]
total_time = [236.52952885627747, 123.48606276512146, 54.41011190414429,13.935796976089478, 15.425882339477539, 14.296817779541016]

# %% [markdown]
# #### Get acquisition times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_get_acq,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_get_acq,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_get_acq,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when retrieving acquisition data w/ different number of analysts',
    xaxis=dict(title=dict(text="Number of analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="895c21ad-1eb2-4145-95ba-d77ad289ec6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("895c21ad-1eb2-4145-95ba-d77ad289ec6c")) {
#                     Plotly.newPlot(
#                         '895c21ad-1eb2-4145-95ba-d77ad289ec6c',
#                         [{"name": "Minimum", "type": "bar", "uid": "e6ee5f93-f0a9-4ba3-83be-eb5dc8dedb9a", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.12300729751586914, 0.15600895881652832, 0.16900968551635742, 0.4470255374908447, 0.37002110481262207, 0.640036582946777]}, {"name": "Average", "type": "bar", "uid": "05a790ad-d191-4a5d-b282-eeaa01d65f2f", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.13422767162323, 0.1760400724411011, 0.31767817735672, 0.5067889785766602, 0.8566490054130554, 1.6696454906463623]}, {"name": "Maximum", "type": "bar", "uid": "9a6e05cc-921d-4e3f-9039-3921639fffea", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [0.20601201057434082, 0.23601365089416504, 0.5260300636291504, 0.6060347557067871, 1.4590833187103271, 3.1581807136535645]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when retrieving acquisition data w/ different number of analysts"}, "xaxis": {"title": {"text": "Number of analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('895c21ad-1eb2-4145-95ba-d77ad289ec6c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Add analysis times (minimum, average & maximum)

# %%
trace1 = go.Bar(
    x=num_analysts,
    y=min_add_ana,
    name='Minimum'
)
trace2 = go.Bar(
    x=num_analysts,
    y=avg_add_ana,
    name='Average'
)
trace3 = go.Bar(
    x=num_analysts,
    y=max_add_ana,
    name='Maximum'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group',
    title='Times obtained when executing tx AddAnalysis w/ different number of analysts',
    xaxis=dict(title=dict(text="Analysts working at same time")),
    yaxis=dict(title=dict(text="Seconds"))
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="8d4401a2-f2a5-47e5-bf5f-bdd9d6af10ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8d4401a2-f2a5-47e5-bf5f-bdd9d6af10ae")) {
#                     Plotly.newPlot(
#                         '8d4401a2-f2a5-47e5-bf5f-bdd9d6af10ae',
#                         [{"name": "Minimum", "type": "bar", "uid": "e1854f31-7972-4c8b-a81f-86d872917222", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.2031259536743164, 2.252128839492798, 2.16512393951416, 0.7230415344238281, 1.2560718059539795, 1.8761072158813477]}, {"name": "Average", "type": "bar", "uid": "c1438c7b-b3bf-46fa-be01-44da8ca1aa20", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.2285774636268614, 2.2897609639167786, 2.392046816349029, 0.8625693464279175, 2.534804975986481, 4.800464570522308]}, {"name": "Maximum", "type": "bar", "uid": "95eea6bd-7857-4297-b073-5eea73b4a189", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [2.3471343517303467, 2.4611406326293945, 2.7161552906036377, 1.0650608539581299, 3.10017728805542, 5.874336004257202]}],
#                         {"barmode": "group", "title": {"text": "Times obtained when executing tx AddAnalysis w/ different number of analysts"}, "xaxis": {"title": {"text": "Analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8d4401a2-f2a5-47e5-bf5f-bdd9d6af10ae');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Total elapsed time to add 100 analysis

# %%
plotly.offline.iplot({
    "data": [go.Bar(x=num_analysts, y=total_time)],
    "layout": go.Layout(
        title="Total elapsed time",
        xaxis=dict(title=dict(text="Analysts working at same time")),
        yaxis=dict(title=dict(text="Seconds"))
    )
})
# Out:
# <div>
#
#
#             <div id="48dd51f1-0e06-4fc2-9f12-070ef4463d55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("48dd51f1-0e06-4fc2-9f12-070ef4463d55")) {
#                     Plotly.newPlot(
#                         '48dd51f1-0e06-4fc2-9f12-070ef4463d55',
#                         [{"type": "bar", "uid": "7f27672a-4807-4909-b871-a63be2a3133f", "x": ["ONE", "TWO", "FIVE", "TEN", "TWENTY FIVE", "FIFTY"], "y": [236.52952885627747, 123.48606276512146, 54.41011190414429, 13.935796976089478, 15.425882339477539, 14.296817779541016]}],
#                         {"title": {"text": "Total elapsed time"}, "xaxis": {"title": {"text": "Analysts working at same time"}}, "yaxis": {"title": {"text": "Seconds"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('48dd51f1-0e06-4fc2-9f12-070ef4463d55');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
